# %%
# import required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# read csv file and convert into dataframe
df1 = pd.read_csv('Country-Code.csv')
df1.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df2 = pd.read_csv('zomato.csv',engine='python',encoding='ISO-8859-1')
df2.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                    Japanese  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
#
# [2 rows x 21 columns]

# %%
# let's merge the dataframes
df = pd.merge(df1,df2,on='Country Code')
df.head(2)
# Out:
#    Country Code Country  Restaurant ID      Restaurant Name  City  \
# 0             1   India        3400025           Jahanpanah  Agra
# 1             1   India        3400341  Rangrezz Restaurant  Agra
#
#                                              Address    Locality  \
# 0  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...  Agra Cantt
# 1  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...  Agra Cantt
#
#    Locality Verbose  Longitude   Latitude  ...            Currency  \
# 0  Agra Cantt, Agra  78.011544  27.161661  ...  Indian Rupees(Rs.)
# 1  Agra Cantt, Agra   0.000000   0.000000  ...  Indian Rupees(Rs.)
#
#    Has Table booking Has Online delivery Is delivering now  \
# 0                 No                  No                No
# 1                 No                  No                No
#
#   Switch to order menu Price range Aggregate rating  Rating color  \
# 0                   No           3              3.9        Yellow
# 1                   No           2              3.5        Yellow
#
#    Rating text Votes
# 0         Good   140
# 1         Good    71
#
# [2 rows x 22 columns]

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows", None)
df.head(2)
# Out:
#    Country Code Country  Restaurant ID      Restaurant Name  City  \
# 0             1   India        3400025           Jahanpanah  Agra
# 1             1   India        3400341  Rangrezz Restaurant  Agra
#
#                                              Address    Locality  \
# 0  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...  Agra Cantt
# 1  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...  Agra Cantt
#
#    Locality Verbose  Longitude   Latitude               Cuisines  \
# 0  Agra Cantt, Agra  78.011544  27.161661  North Indian, Mughlai
# 1  Agra Cantt, Agra   0.000000   0.000000  North Indian, Mughlai
#
#    Average Cost for two            Currency Has Table booking  \
# 0                   850  Indian Rupees(Rs.)                No
# 1                   700  Indian Rupees(Rs.)                No
#
#   Has Online delivery Is delivering now Switch to order menu  Price range  \
# 0                  No                No                   No            3
# 1                  No                No                   No            2
#
#    Aggregate rating Rating color Rating text  Votes
# 0               3.9       Yellow        Good    140
# 1               3.5       Yellow        Good     71

# %% [markdown]
# ## Observations:
# ### Firstly we observe the dataset:
#
# - Country Code: Country in which restaurant is located
# - Country: name of the country
# - Restaurant Id: Unique id of every restaurant across various cities of the world
# - Restaurant Name: Name of the restaurant
# - City: City in which restaurant is located
# - Address: Address of the restaurant
# - Locality: Location in the city
# - Locality Verbose: Detailed description of the locality
# - Longitude: Longitude coordinate of the restaurant
# - Latitude: Latitude coordinate of the restaurant
# - Cuisines: Cuisines offered by the restaurant
# - Average Cost for two: Cost for two people in different currencies
# - Currency: Currency of the country
# - Has Table booking: yes/no
# - Has Online delivery: yes/ no
# - Is delivering: yes/ no
# - Switch to order menu: yes/no
# - Price range: range of price of food
# - Aggregate Rating: Average rating out of 5
# - Rating color: depending upon the average rating color
# - Rating text: text on the basis of rating of rating
# - Votes: Number of ratings casted by people
#
# ## Problem statement : In this dataset predict 2 things –
# - Average Cost for two
# - Price range

# %%
df.columns
# Out:
# Index(['Country Code', 'Country', 'Restaurant ID', 'Restaurant Name', 'City',
#        'Address', 'Locality', 'Locality Verbose', 'Longitude', 'Latitude',
#        'Cuisines', 'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.shape
# Out:
# (9551, 22)

# %% [markdown]
# ### We have 9551 rows and 22 columns

# %%
df.isna().sum()
# Out:
# Country Code            0
# Country                 0
# Restaurant ID           0
# Restaurant Name         0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# ### Cuisines column has null values present

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          9551 non-null   int64
#  1   Country               9551 non-null   object
#  2   Restaurant ID         9551 non-null   int64
#  3   Restaurant Name       9551 non-null   object
#  4   City                  9551 non-null   object
#  5   Address               9551 non-null   object
#  6   Locality              9551 non-null   object
#  7   Locality Verbose      9551 non-null   object
#  8   Longitude             9551 non-null   float64
#  9   Latitude              9551 non-null   float64
#  10  Cuisines              9542 non-null   object
#  11  Average Cost for two  9551 non-null   int64
#  12  Currency              9551 non-null   object
#  13  Has Table booking     9551 non-null   object
#  14  Has Online delivery   9551 non-null   object
#  15  Is delivering now     9551 non-null   object
#  16  Switch to order menu  9551 non-null   object
#  17  Price range           9551 non-null   int64
#  18  Aggregate rating      9551 non-null   float64
#  19  Rating color          9551 non-null   object
#  20  Rating text           9551 non-null   object
#  21  Votes                 9551 non-null   int64
# dtypes: float64(3), int64(5), object(14)
# memory usage: 1.7+ MB

# %% [markdown]
# ### Most of the features are having object type values .we will use encoding techniques to handles this situation.

# %%
# let's check the duplicate rows present or not in this dataset
duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [Country Code, Country, Restaurant ID, Restaurant Name, City, Address, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes]
# Index: []

# %% [markdown]
# ### There is no duplicates present

# %%
df.nunique()
# Out:
# Country Code              15
# Country                   15
# Restaurant ID           9551
# Restaurant Name         7446
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# dtype: int64

# %%
# lets drop unnecessary columns from dataset
df.drop(columns='Switch to order menu',inplace =True)
df.drop(columns=['Country Code','Restaurant ID','Address','Locality Verbose','Is delivering now'],inplace =True)

# %%
# stats about data
df.describe()
# Out:
#          Longitude     Latitude  Average Cost for two  Price range  \
# count  9551.000000  9551.000000           9551.000000  9551.000000
# mean     64.126574    25.854381           1199.210763     1.804837
# std      41.467058    11.007935          16121.183073     0.905609
# min    -157.948486   -41.330428              0.000000     1.000000
# 25%      77.081343    28.478713            250.000000     1.000000
# 50%      77.191964    28.570469            400.000000     2.000000
# 75%      77.282006    28.642758            700.000000     2.000000
# max     174.832089    55.976980         800000.000000     4.000000
#
#        Aggregate rating         Votes
# count       9551.000000   9551.000000
# mean           2.666370    156.909748
# std            1.516378    430.169145
# min            0.000000      0.000000
# 25%            2.500000      5.000000
# 50%            3.200000     31.000000
# 75%            3.700000    131.000000
# max            4.900000  10934.000000

# %%
df.describe()
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),annot=True,fmt='f',cmap='coolwarm')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("VARIABLES SUMMARY")
plt.show()

# %% [markdown]
# ## Observations:-
# - In variable summery Average Cost for two and Votes indicating the presence of outliers

# %%
# print all the datatypes and unique values
for column in df.columns:
    if df[column].dtype== object:
        print(str(column) + ':' + str(df[column].unique()))
        print(df[column].value_counts())
        print('---------------------------------------------------------------------------------')
# Out:
# Country:['India' 'Australia' 'Brazil' 'Canada' 'Indonesia' 'New Zealand'
#  'Phillipines' 'Qatar' 'Singapore' 'South Africa' 'Sri Lanka' 'Turkey'
#  'UAE' 'United Kingdom' 'United States']
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64
# ---------------------------------------------------------------------------------
# Restaurant Name:['Jahanpanah' 'Rangrezz Restaurant' 'Time2Eat - Mama Chicken' ...
#  'Tokyo Japanese Steak House' "Theo Yianni's Authentic Greek Restaurant"
#  "Fishpatrick's Crabby Cafe"]
# Cafe Coffee Day                                           83
# Domino's Pizza                                            79
# Subway                                                    63
# Green Chick Chop                                          51
# McDonald's                                                48
# Keventers                                                 34
# Pizza Hut                                                 30
# Giani                                                     29
# Baskin Robbins                                            28
# Barbeque Nation                                           26
# Dunkin' Donuts                                            22
# Giani's                                                   22
# Barista                                                   22
# Costa Coffee                                              20
# Pind Balluchi                                             20
# Sagar Ratna                                               19
# Twenty Four Seven                                         19
# Pizza Hut Delivery                                        19
# Wah Ji Wah                                                19
# KFC                                                       18
# Starbucks                                                 18
# Republic of Chicken                                       18
# Chaayos                                                   18
# Burger King                                               16
# Haldiram's                                                16
# Shree Rathnam                                             15
# Bikanervala                                               14
# Frontier                                                  14
# Aggarwal Sweets                                           14
# Moti Mahal Delux                                          14
# Bikaner Sweets                                            13
# Karim's                                                   13
# Behrouz Biryani                                           13
# Chicago Pizza                                             12
# 34, Chowringhee Lane                                      12
# Apni Rasoi                                                12
# Wow! Momo                                                 11
# Madras Cafe                                               11
# Burger Point                                              11
# Gopala                                                    10
# Nirula's Ice Cream                                         9
# Berco's                                                    9
# Yo! China                                                  9
# Cocoberry                                                  9
# Shama Chicken Corner                                       9
# Sardar A Pure Meat Shop                                    9
# Faasos                                                     8
# Punjabi Tadka                                              8
# Angels in my Kitchen                                       8
# Chowringhee                                                8
# Kebab Xpress                                               8
# Ovenstory Pizza                                            8
# Punjabi Chaap Corner                                       8
# Tpot                                                       7
# Tibb's Frankie                                             7
# BTW                                                        7
# RollsKing                                                  7
# Slice of Italy                                             7
# Mocha                                                      7
# Khan Chacha                                                7
# Nazeer Foods                                               7
# Chawla's_                                                 7
# Chinese Hut                                                7
# China Town                                                 7
# Dolce Gelato                                               7
# The Yellow Chilli                                          7
# Mainland China                                             6
# Al Bake                                                    6
# Punjabi Rasoi                                              6
# Pudding & Pie                                              6
# Southy                                                     6
# Bikaner Sweets & Restaurant                                6
# TGI Friday's                                               6
# Moti Mahal Delux Tandoori Trail                            6
# The Beer Cafe                                              6
# Farzi Cafe                                                 6
# Sanjha Chulha                                              6
# The Diet Kitchen                                           6
# Biryani Blues                                              6
# Wrapss                                                     6
# Kings Kulfi                                                6
# Goli Vada Pav No. 1                                        6
# Cafe Coffee Day - The Lounge                               6
# Mr. Sub                                                    6
# The Chinese Hut                                            5
# Red Chilli                                                 5
# Shree Bikaner Misthan Bhandar                              5
# Chili's                                                    5
# Flirty Momo's                                              5
# Nathu's Sweets                                             5
# Texas Roadhouse                                            5
# Mad Over Donuts                                            5
# Aggarwal Sweet India                                       5
# Nukkadwala                                                 5
# Punjab Grill                                               5
# Sandoz                                                     5
# Kettle & Kegs                                              5
# Happy Hakka                                                5
# The Midnight Heroes                                        5
# Da Pizza Corner                                            5
# Aggarwal Sweet Corner                                      5
# SGF - Spice Grill Flame                                    5
# Chinese Corner                                             5
# Swagath                                                    5
# Pita Pit                                                   5
# Instapizza                                                 5
# Nando's                                                    5
# L'Opera                                                    5
# Kake Da Hotel                                              5
# Viva Hyderabad                                             5
# Captain Grub                                               5
# Cake Point                                                 5
# Momo-Cha                                                   4
# Zaika                                                      4
# Meatwale.com                                               4
# Gelato Vinto                                               4
# Aapki Rasoi                                                4
# Big Chill                                                  4
# Pirates of Grill                                           4
# Qureshi's Kabab Corner                                     4
# South Indian Hut                                           4
# Nirula's                                                   4
# Chaska                                                     4
# Hong Kong Express                                          4
# GoGourmet                                                  4
# Puri Bakers                                                4
# Pakwan                                                     4
# The Coffee Bean & Tea Leaf                                 4
# Applebee's                                                 4
# Rainbows                                                   4
# FreshMenu                                                  4
# Tea Villa Cafe                                             4
# Nite Bites                                                 4
# Public Cafe                                                4
# Jamie's Italian                                            4
# Bun Intended                                               4
# Deez Biryani & Kebabs                                      4
# Gola Sizzlers                                              4
# Jungle Jamboree                                            4
# Punjabi Zaika                                              4
# Open Oven                                                  4
# Super Cake Shop                                            4
# Sugar & Spice - Le Marche                                  4
# Chawla's 2                                                 4
# Kwality Wall's Swirl's                                     4
# Mx Corn                                                    4
# Burger Xpress                                              4
# Bawarchi                                                   4
# Punjabi's Veg Grill                                        4
# Hot Pot                                                    4
# Nizam's Kathi Kabab                                        4
# DCK- Dana Choga's Kitchen                                  4
# Chai Point                                                 4
# Colonel's Kababz                                           4
# The Kathis                                                 4
# Kathi Junction                                             4
# AB's - Absolute Barbecues                                  4
# Chai Garam                                                 4
# Zizo                                                       3
# Finger Licious                                             3
# Bake N Shake                                               3
# Chimney                                                    3
# Niti Shake & Ice Cream Hub                                 3
# Doughlicious                                               3
# Pizza Station                                              3
# Little Chef                                                3
# Burger Singh                                               3
# Bats On Delivery                                           3
# Chaophraya                                                 3
# Food Plaza                                                 3
# New Madras Cafe                                            3
# Dilli Darbar                                               3
# Biryani By Kilo                                            3
# Aggarwal Sweets India                                      3
# Chinese Food Corner                                        3
# Street Foods by Punjab Grill                               3
# Tikka Junction                                             3
# True Blue                                                  3
# The Chaiwalas                                              3
# The Golden Dragon                                          3
# Jaiveer Naan & Chaap                                       3
# Tea Halt                                                   3
# Midnight Hunger Hub                                        3
# Saravana Bhavan                                            3
# Indian Coffee House                                        3
# Cakes & Bakes                                              3
# Dí_ner Grill                                               3
# Muradabadi Shahi Biryani & Chicken Corner                  3
# Punjabi Dhaba                                              3
# Mr. Brown                                                  3
# Riyaz Biryani Corner                                       3
# Chawla's Chic Inn                                          3
# 221 B Baker Street                                         3
# Movenpick                                                  3
# Joost Juice Bar                                            3
# Hangchuaa's Chinese Food Corner                            3
# Baked Buns                                                 3
# Naivedyam                                                  3
# Zaffran                                                    3
# Gazebo                                                     3
# Aggarwal Sweet Centre                                      3
# Kanwarji's                                                 3
# Bunty Dhaba                                                3
# Roll Club                                                  3
# Veg Ex                                                     3
# Bharat Sweets                                              3
# The Chai Story                                             3
# Sushiya Express                                            3
# Urban Punjab                                               3
# Desi Vibes                                                 3
# HuHot Mongolian Grill                                      3
# Captain Bill$ Deliverz                                     3
# Habibi Express                                             3
# Wah G Wah                                                  3
# Just Vada Pav                                              3
# Aggarwal Bikaner Sweets                                    3
# Onesta                                                     3
# Side Wok                                                   3
# Foodies                                                    3
# Amul Ice-Cream Parlour                                     3
# Om Sweets & Snacks                                         3
# Big Yellow Door                                            3
# Mamagoto                                                   3
# La Pino'z Pizza                                            3
# Goosebumps                                                 3
# Defence Bakery                                             3
# SodaBottleOpenerWala                                       3
# Flying Cakes                                               3
# Health Buzzz                                               3
# Shahenshah                                                 3
# Krispy Kreme                                               3
# Amici Cafe                                                 3
# Punjabi Pakwaan                                            3
# Radha Swami Shudh Vaishno Dhaba                            3
# BarShala                                                   3
# Havmor Ice Cream                                           3
# Kerala Cafe                                                3
# Breaktym                                                   3
# Food Scouts                                                3
# Pizza Hub                                                  3
# Rollmaal                                                   3
# Palmshore                                                  3
# The Fisherman's Wharf                                      3
# Foodhall                                                   3
# Taco Bell                                                  3
# Hira Sweets                                                3
# Polka Pastry & Snack Bar                                   3
# KB's Kulfi & Icecream                                      3
# Shawarma Wala                                              3
# Cafe Delhi Heights                                         3
# Punjab Restaurant                                          3
# Wok On Fire                                                3
# Mitra Da Dhaba                                             3
# Chinese Food                                               3
# Bikkgane Biryani                                           3
# Hard Rock Cafe                                             3
# QD's Restaurant                                            3
# Chawla's Tandoori Junction                                 3
# Speedy Chow                                                3
# Talaga Sampireun                                           3
# Changezi Chicken                                           3
# Sri Balaji                                                 3
# Not Just Paranthas                                         3
# Tikka Town                                                 3
# Cafe Turtle                                                3
# Hasty Tasty                                                3
# Sagar Dhaba                                                2
# Chawla's Tandoori Xpress                                   2
# Bakers Oven                                                2
# The Cheesecake Factory                                     2
# Chutneez Restaurant Lounge & Bar                           2
# AB's Absolute Barbecues                                    2
# Gupta Ji Ka Dhaba                                          2
# Pho King Awesome                                           2
# Wild Chef House                                            2
# Dabba Meat                                                 2
# Yomo-Your Only Momo Outlet                                 2
# Crust N Cakes                                              2
# The Roll Van                                               2
# The Tandoor                                                2
# A Piece of Paris                                           2
# Munch Nation                                               2
# Madras Coffee House                                        2
# Wagh Bakri Tea Lounge                                      2
# ZASTY                                                      2
# Tamura                                                     2
# Chalte Firte Momos & Special Foods                         2
# Thai, Chinese, Seafood                                                                             1
# Continental, Chinese, Italian, Finger Food                                                         1
# Bakery, Desserts, Fast Food, Beverages                                                             1
# North Indian, South Indian, Chinese, Fast Food, Bakery, Mithai                                     1
# Italian, Mexican, Lebanese, Continental                                                            1
# Finger Food, Italian                                                                               1
# Continental, Chinese, Japanese, North Indian, Thai                                                 1
# European, Sushi, Italian                                                                           1
# European, Asian, North Indian, Italian, Continental, Pizza                                         1
# Chinese, Seafood, Thai                                                                             1
# South Indian, North Indian, Street Food, Chinese, Mithai                                           1
# Turkish, Mediterranean, Middle Eastern                                                             1
# Lebanese, Chinese, Fast Food                                                                       1
# American, Italian, Mughlai, North Indian                                                           1
# Bakery, Desserts, Ice Cream                                                                        1
# Cafe, Fast Food, Continental                                                                       1
# Cafe, Italian, Continental, Fast Food                                                              1
# Continental, Chinese, Thai                                                                         1
# North Indian, Continental, South Indian, Chinese                                                   1
# American, Mexican, Finger Food                                                                     1
# British, Chinese, Italian                                                                          1
# Mexican, Italian, American                                                                         1
# North Indian, Continental, Italian, Finger Food                                                    1
# Burger, American, Fast Food, Italian, Pizza                                                        1
# Chinese, Healthy Food                                                                              1
# Kashmiri, Chinese, Mughlai                                                                         1
# North Indian, Fast Food, Continental                                                               1
# South Indian, North Indian, Chinese, Fast Food, Street Food, Mithai                                1
# Chinese, Thai, Seafood, Naga                                                                       1
# Healthy Food, Juices, Salad                                                                        1
# Mithai, Street Food, North Indian, South Indian, Chinese, Fast Food, Beverages                     1
# North Indian, Kashmiri, Chinese, Thai, Korean                                                      1
# Japanese, Chinese, Asian, Thai                                                                     1
# Continental, Chinese, Thai, Mediterranean                                                          1
# European, Italian, Cafe                                                                            1
# American, British, Continental                                                                     1
# American, North Indian, European, Asian                                                            1
# North Indian, Chinese, Thai, Italian, Middle Eastern                                               1
# Continental, Tex-Mex                                                                               1
# American, Continental, North Indian, Chinese                                                       1
# Continental, Asian, Italian, Mediterranean, Burger                                                 1
# Continental, American, Italian, Bakery                                                             1
# Continental, Kerala                                                                                1
# North Indian, Italian, Continental, Chinese                                                        1
# Cafe, Mexican, Continental                                                                         1
# North Indian, Continental, Asian, Italian                                                          1
# Continental, Cafe                                                                                  1
# North Indian, Biryani, Mughlai                                                                     1
# Burger, Greek, Sandwich                                                                            1
# Name: Cuisines, dtype: int64
# ---------------------------------------------------------------------------------
# Currency:['Indian Rupees(Rs.)' 'Dollar($)' 'Brazilian Real(R$)'
#  'Indonesian Rupiah(IDR)' 'NewZealand($)' 'Botswana Pula(P)'
#  'Qatari Rial(QR)' 'Rand(R)' 'Sri Lankan Rupee(LKR)' 'Turkish Lira(TL)'
#  'Emirati Diram(AED)' 'Pounds(\x8c£)']
# Indian Rupees(Rs.)        8652
# Dollar($)                  482
# Pounds(£)                  80
# Brazilian Real(R$)          60
# Rand(R)                     60
# Emirati Diram(AED)          60
# NewZealand($)               40
# Turkish Lira(TL)            34
# Botswana Pula(P)            22
# Indonesian Rupiah(IDR)      21
# Qatari Rial(QR)             20
# Sri Lankan Rupee(LKR)       20
# Name: Currency, dtype: int64
# ---------------------------------------------------------------------------------
# Has Table booking:['No' 'Yes']
# No     8393
# Yes    1158
# Name: Has Table booking, dtype: int64
# ---------------------------------------------------------------------------------
# Has Online delivery:['No' 'Yes']
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64
# ---------------------------------------------------------------------------------
# Rating color:['Yellow' 'Green' 'Orange' 'Dark Green' 'White' 'Red']
# Orange        3737
# White         2148
# Yellow        2100
# Green         1079
# Dark Green     301
# Red            186
# Name: Rating color, dtype: int64
# ---------------------------------------------------------------------------------
# Rating text:['Good' 'Very Good' 'Average' 'Excellent' 'Not rated' 'Poor']
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: Rating text, dtype: int64
# ---------------------------------------------------------------------------------

# %% [markdown]
# # EDA

# %%
#pie chart to represent the country where zomato is widely used
plt.pie(df["Country"].value_counts().head(3),labels=df["Country"].value_counts().head(3).index,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# ### Zomato most of the  transactions are from India followed by United States and then United Kingdom

# %%
# lets visualize the all countries
sns.countplot(y= df['Country'],data= df)
plt.show()

# %%
df['Country'].value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %% [markdown]
# ## Understanding the ratings

# %%
ratings = df.groupby(['Aggregate rating','Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# 15               3.2       Orange     Average           522
# 16               3.3       Orange     Average           483
# 17               3.4       Orange     Average           498
# 18               3.5       Yellow        Good           480
# 19               3.6       Yellow        Good           458
# 20               3.7       Yellow        Good           427
# 21               3.8       Yellow        Good           400
# 22               3.9       Yellow        Good           335
# 23               4.0        Green   Very Good           266
# 24               4.1        Green   Very Good           274
# 25               4.2        Green   Very Good           221
# 26               4.3        Green   Very Good           174
# 27               4.4        Green   Very Good           144
# 28               4.5   Dark Green   Excellent            95
# 29               4.6   Dark Green   Excellent            78
# 30               4.7   Dark Green   Excellent            42
# 31               4.8   Dark Green   Excellent            25
# 32               4.9   Dark Green   Excellent            61

# %% [markdown]
# ### Obseravtions: The above information helps us to understand the relationship between 'Aggregate rating', 'Rating color' and 'Rating text'. We conclude the following color assigned to the ratings:
#
# - Rating 0 - White - Not rated
#
# - Rating 1.8 to 2.4 - Red - Poor
#
# - Rating 2.5 to 3.4 - Orange - Average
#
# - Rating 3.5 to 3.9 - Yellow - Good
#
# - Rating 4.0 to 4.4 - Green - Very Good
#
# - Rating 4.5 to 4.9 - Dark Green - Excellent

# %%
#plotting the count of each rating
plt.figure(figsize=(12,6))
sns.barplot(x="Aggregate rating",y="Rating Count",data=ratings)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
#plotting the count of rating with the color assigned to them in the dataset 
plt.figure(figsize=(12,6))
sns.barplot(x="Aggregate rating",y="Rating Count",data=ratings,hue="Rating color",palette=["blue","red","orange","yellow","green","green"])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %% [markdown]
# ### Observation:
#
# - Not rated count is the highest
# - Maximum ratings are between 2.5 to 3.4

# %%
sns.countplot(x='Rating color' ,data = ratings,palette=["blue","red","orange","yellow","green","green"] )
plt.show()

# %%
No_rating = df[df['Rating color']=='White'].groupby('Country').size().reset_index().rename(columns={0:'Rating Count'})
No_rating
# Out:
#           Country  Rating Count
# 0          Brazil             5
# 1           India          2139
# 2  United Kingdom             1
# 3   United States             3

# %% [markdown]
# ### Maximum no. of 0 ratings are from Indian Customers

# %% [markdown]
# ## Understanding Currency

# %%
#the currency which is used in different country 
df.groupby(["Country",'Currency']).size().reset_index().rename(columns={0:"Count"})
# Out:
#            Country                Currency  Count
# 0        Australia               Dollar($)     24
# 1           Brazil      Brazilian Real(R$)     60
# 2           Canada               Dollar($)      4
# 3            India      Indian Rupees(Rs.)   8652
# 4        Indonesia  Indonesian Rupiah(IDR)     21
# 5      New Zealand           NewZealand($)     40
# 6      Phillipines        Botswana Pula(P)     22
# 7            Qatar         Qatari Rial(QR)     20
# 8        Singapore               Dollar($)     20
# 9     South Africa                 Rand(R)     60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)     20
# 11          Turkey        Turkish Lira(TL)     34
# 12             UAE      Emirati Diram(AED)     60
# 13  United Kingdom              Pounds(£)     80
# 14   United States               Dollar($)    434

# %%
# no. of outlets in zomato which accepts online delivery
df["Has Online delivery"].value_counts()
# Out:
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64

# %%
#country where the resturants on zomato are providing the online delivery option 
df[df["Has Online delivery"]=="Yes"].groupby("Country").size()
# Out:
# Country
# India    2423
# UAE        28
# dtype: int64

# %%
country_online_delivery = df.groupby(["Has Online delivery", 'Country']).size().reset_index(name='count')
country_online_delivery
# Out:
#    Has Online delivery         Country  count
# 0                   No       Australia     24
# 1                   No          Brazil     60
# 2                   No          Canada      4
# 3                   No           India   6229
# 4                   No       Indonesia     21
# 5                   No     New Zealand     40
# 6                   No     Phillipines     22
# 7                   No           Qatar     20
# 8                   No       Singapore     20
# 9                   No    South Africa     60
# 10                  No       Sri Lanka     20
# 11                  No          Turkey     34
# 12                  No             UAE     32
# 13                  No  United Kingdom     80
# 14                  No   United States    434
# 15                 Yes           India   2423
# 16                 Yes             UAE     28

# %%
plt.figure(figsize=(15,8))
sns.countplot(hue='Has Online delivery',x='Country',data=country_online_delivery)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %% [markdown]
# ### Online delivery is available in India and UAE only

# %%
# no. of outlets in zomato which accepts table booking
df["Has Table booking"].value_counts()
# Out:
# No     8393
# Yes    1158
# Name: Has Table booking, dtype: int64

# %%
#locality where the resturants on zomato are providing the table booking option 
df[df["Has Table booking"]=="Yes"].groupby("Locality").size()
# Out:
# Locality
#  ILD Trade Centre Mall, Sohna Road                      1
# 12th Square Building, Banjara Hills                     1
# Adchini                                                 5
# Addition Hills                                          1
# Aditya Mega Mall, Karkardooma                           2
# Adyar                                                   1
# Aerocity                                                1
# Aggarwal City Mall, Pitampura                           2
# Aggarwal City Plaza, Rohini                             1
# Al Barari                                               1
# Al Dhafrah                                              1
# Al Karama                                               2
# Albemarle Street, Mayfair                               1
# Ambience Mall, Gurgaon                                  2
# Ambience Mall, Vasant Kunj                              4
# Anand Lok                                               1
# Andaz Delhi, Aerocity                                   1
# Anna Nagar East                                         2
# Ansal Plaza Mall, Greater Noida                         1
# Ansal Plaza Mall, Khel Gaon Marg                        3
# Ashok Nagar                                             1
# Ashok Vihar Phase 1                                     1
# Ashok Vihar Phase 2                                     5
# Sector 93                                               1
# Select Citywalk Mall, Saket                             6
# Senapati Bapat Road                                     2
# Shahpur Jat                                             6
# Shangri La's - Eros hotel, Janpath                      5
# Sheraton New Delhi Hotel, Saket                         3
# Shipra Mall, Indirapuram                                3
# Silver Spring Arcade, Science City Area                 1
# Sofitel Philippine Plaza Manila, Pasay City             1
# Sohna Road                                              8
# Souq Waqif                                              1
# South City 1                                            1
# South Extension 1                                       1
# South Extension 2                                       5
# Southern Avenue                                         1
# Southern Park Mall, Saket                               2
# Spice World Mall, Sector 25                             1
# Spot 18 Mall, Pimple Saudagar                           1
# Star City Mall, Mayur Vihar Phase 1                     4
# Subhash Nagar                                           1
# Suncity Business Tower, Golf Course Road                1
# Sunder Nagar                                            3
# Supermart 1, DLF Phase 4                                5
# Supertech Shopprix Mall, Sector 61                      5
# Sushant Lok                                             1
# T. Nagar                                                1
# TDI Mall, Rajouri Garden                                1
# Tagaytay City                                           1
# Tagore Garden                                           3
# Taj Vivanta, Khan Market                                2
# The Ashok, Chanakyapuri                                 4
# The Atrium, Suraj Kund                                  1
# The Bristol Hotel, DLF Phase 1                          3
# The Claremont, MG Road                                  1
# The Claridges, Aurangzeb Road                           4
# The Galgotias, Sector 23                                1
# The Grand New Delhi, Vasant Kunj                        2
# The Great India Place, Sector 38                        9
# The Habitare Hotel, Sector 14                           2
# The Imperial, Janpath                                   8
# The India Mall, New Friends Colony                      3
# The Lalit New Delhi, Barakhamba Road                    5
# The Leela Ambience Convention Hotel                     4
# The Leela Palace, Chanakyapuri                          3
# The Lodhi, Lodhi Road                                   1
# The Midland, Deansgate                                  1
# The Park, Connaught Place                               3
# The Pllazio Hotel, Sector 29                            1
# The Suryaa New Delhi, New Friends Colony                2
# The Taj Mahal Hotel, Mansingh Road                      4
# The Taj Palace Hotel, Chanakyapuri                      3
# The Uppal, Aerocity                                     2
# The Village Restaurant Complex, Khel Gaon Marg          3
# The Westin Gurgaon, Sector 29                           3
# The Westin Sohna Resort & Spa, Sohna Road               1
# Two Horizon Center, Golf Course Road                    2
# Udyog Vihar                                             1
# Umm Hurair                                              1
# Unitech Infospace, Sector 21, Gurgaon                   3
# V3S Mall, Laxmi Nagar                                   6
# Vasant Kunj                                             5
# Vasant Square Mall, Vasant Kunj                         1
# Vasant Vihar                                            3
# Velachery                                               1
# Venetian Village, Al Maqtaa                             1
# Versova, Andheri West                                   1
# Vibe by The LaLit Traveller, Mathura Road               1
# Vijay Nagar                                             4
# Vikaspuri                                               4
# Vile Parle East                                         1
# Viman Nagar                                             1
# Vivanta by Taj, Sector 44, Gurgaon                      2
# Wakad                                                   1
# West Gate Mall, Rajouri Garden                          1
# Woods Resort, Gurgaon                                   1
# World Trade Center Mall, Al Markaziya                   1
# Yusuf Sarai                                             1
# ibis New Delhi, Aerocity                                1
# dtype: int64

# %%
zomato_locality_booking = df.groupby([ 'Has Table booking',"Locality"]).size().reset_index(name='count').sort_values(by=['count'], ascending=False)
zomato_locality_booking.head(10)
# Out:
#     Has Table booking             Locality  count
# 872                No             Shahdara     87
# 709                No            Pitampura     82
# 581                No  Mayur Vihar Phase 1     80
# 490                No        Krishna Nagar     76
# 744                No       Rajinder Nagar     76
# 568                No        Malviya Nagar     76
# 856                No            Sector 62     73
# 775                No           Safdarjung     73
# 791                No         Satyaniketan     71
# 448                No              Kalkaji     71

# %%
#city which has placed the most no. of orders on zomato
df["City"].value_counts().head(20)
# Out:
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
# Amritsar            21
# Lucknow             21
# Ahmedabad           21
# Bhubaneshwar        21
# Guwahati            21
# Dalton              20
# Davenport           20
# Sí£o Paulo          20
# Rio de Janeiro      20
# Agra                20
# Brasí_lia           20
# Auckland            20
# Des Moines          20
# Dubuque             20
# Gainesville         20
# Name: City, dtype: int64

# %%
#representing the city in pie chart representation
plt.pie(df["City"].value_counts().head(5),labels=df["City"].value_counts().head(5).index,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# ### New Delhi has the most no. of orders from all the cities

# %% [markdown]
# ## Extracing top-10 cuisines

# %%
#the most famous and regularly ordered cuisines on zomato
top_cuisines=df["Cuisines"].value_counts()[:10]
top_cuisines
# Out:
# North Indian                      936
# North Indian, Chinese             511
# Fast Food                         354
# Chinese                           354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: Cuisines, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(y=top_cuisines,x= top_cuisines.index)
plt.xticks(rotation=90)
plt.xlabel("Name of the Cuisines")
plt.show()

# %% [markdown]
# ### North Indian was the most ordered food online on zomato

# %% [markdown]
# ## 25 costly restaurants for 2 people around the globe

# %%
costly_zomato = df.nlargest(25, 'Average Cost for two')
costly_zomato.head()
# Out:
#         Country              Restaurant Name     City  \
# 8747  Indonesia                         Skye  Jakarta
# 8748  Indonesia     Satoo - Hotel Shangri-La  Jakarta
# 8751  Indonesia                   Sushi Masa  Jakarta
# 8753  Indonesia               3 Wise Monkeys  Jakarta
# 8758  Indonesia  Avec Moi Restaurant and Bar  Jakarta
#
#                            Locality   Longitude  Latitude  \
# 8747  Grand Indonesia Mall, Thamrin  106.821999 -6.196778
# 8748     Hotel Shangri-La, Sudirman  106.818961 -6.203292
# 8751                    Penjaringan  106.800144 -6.101298
# 8753                       Senopati  106.813400 -6.235241
# 8758                        Thamrin  106.821023 -6.196270
#
#                         Cuisines  Average Cost for two  \
# 8747        Italian, Continental                800000
# 8748  Asian, Indonesian, Western                800000
# 8751             Sushi, Japanese                500000
# 8753                    Japanese                450000
# 8758             French, Western                350000
#
#                     Currency Has Table booking Has Online delivery  \
# 8747  Indonesian Rupiah(IDR)                No                  No
# 8748  Indonesian Rupiah(IDR)                No                  No
# 8751  Indonesian Rupiah(IDR)                No                  No
# 8753  Indonesian Rupiah(IDR)                No                  No
# 8758  Indonesian Rupiah(IDR)                No                  No
#
#       Price range  Aggregate rating Rating color Rating text  Votes
# 8747            3               4.1        Green   Very Good   1498
# 8748            3               4.6   Dark Green   Excellent    873
# 8751            3               4.9   Dark Green   Excellent    605
# 8753            3               4.2        Green   Very Good    395
# 8758            3               4.3        Green   Very Good    243

# %%
costly_zomato.columns
# Out:
# Index(['Country', 'Restaurant Name', 'City', 'Locality', 'Longitude',
#        'Latitude', 'Cuisines', 'Average Cost for two', 'Currency',
#        'Has Table booking', 'Has Online delivery', 'Price range',
#        'Aggregate rating', 'Rating color', 'Rating text', 'Votes'],
#       dtype='object')

# %%
plt.figure(figsize=(15,8))
sns.barplot(y='Restaurant Name',x='Average Cost for two',data=costly_zomato)
# Out:
# <AxesSubplot:xlabel='Average Cost for two', ylabel='Restaurant Name'>

# %%
price_zomato = df.nlargest(25, 'Price range')
price_zomato.head()
# Out:
#    Country               Restaurant Name  City  \
# 5    India                     MoMo Cafe  Agra
# 6    India         Peshawri - ITC Mughal  Agra
# 7    India         Taj Bano - ITC Mughal  Agra
# 9    India  Dawat-e-Nawab - Radisson Blu  Agra
# 14   India                  Bon Barbecue  Agra
#
#                                Locality  Longitude   Latitude  \
# 5   Courtyard by Marriott Agra, Tajganj   0.000000   0.000000
# 6                   ITC Mughal, Tajganj  78.044095  27.160934
# 7                   ITC Mughal, Tajganj  78.044095  27.160934
# 9                 Radisson Blu, Tajganj  78.057044  27.163303
# 14                              Tajganj   0.000000   0.000000
#
#                               Cuisines  Average Cost for two  \
# 5               North Indian, European                  2000
# 6                North Indian, Mughlai                  2500
# 7                              Mughlai                  2500
# 9                North Indian, Mughlai                  3600
# 14  North Indian, Chinese, Continental                  1500
#
#               Currency Has Table booking Has Online delivery  Price range  \
# 5   Indian Rupees(Rs.)                No                  No            4
# 6   Indian Rupees(Rs.)                No                  No            4
# 7   Indian Rupees(Rs.)                No                  No            4
# 9   Indian Rupees(Rs.)                No                  No            4
# 14  Indian Rupees(Rs.)                No                  No            4
#
#     Aggregate rating Rating color Rating text  Votes
# 5                4.0        Green   Very Good     45
# 6                4.3        Green   Very Good    133
# 7                4.0        Green   Very Good     41
# 9                3.8       Yellow        Good     46
# 14               3.8       Yellow        Good     57

# %%
plt.figure(figsize=(15,8))
sns.barplot(y='Restaurant Name',x='Price range',data=price_zomato)
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='Restaurant Name'>

# %%
# let's visualize the longitude and latitude with primary_fuel
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sns.barplot(y='Latitude',x = 'Price range',data = df)
plt.subplot(1,2,2)
sns.barplot(y='Longitude',x = 'Price range',data = df)
plt.show()

# %%
df.shape
# Out:
# (9551, 16)

# %%
df.head()
# Out:
#   Country                        Restaurant Name  City     Locality  \
# 0   India                             Jahanpanah  Agra   Agra Cantt
# 1   India                    Rangrezz Restaurant  Agra   Agra Cantt
# 2   India                Time2Eat - Mama Chicken  Agra   Agra Cantt
# 3   India  Chokho Jeeman Marwari Jain Bhojanalya  Agra  Civil Lines
# 4   India                         Pinch Of Spice  Agra  Civil Lines
#
#    Longitude   Latitude                        Cuisines  Average Cost for two  \
# 0  78.011544  27.161661           North Indian, Mughlai                   850
# 1   0.000000   0.000000           North Indian, Mughlai                   700
# 2  78.011608  27.160832                    North Indian                   500
# 3  77.998092  27.195928                      Rajasthani                   400
# 4  78.007553  27.201725  North Indian, Chinese, Mughlai                  1000
#
#              Currency Has Table booking Has Online delivery  Price range  \
# 0  Indian Rupees(Rs.)                No                  No            3
# 1  Indian Rupees(Rs.)                No                  No            2
# 2  Indian Rupees(Rs.)                No                  No            2
# 3  Indian Rupees(Rs.)                No                  No            2
# 4  Indian Rupees(Rs.)                No                  No            3
#
#    Aggregate rating Rating color Rating text  Votes
# 0               3.9       Yellow        Good    140
# 1               3.5       Yellow        Good     71
# 2               3.6       Yellow        Good     94
# 3               4.0        Green   Very Good     87
# 4               4.2        Green   Very Good    177

# %%
# converting text into numbers using label encoder
from sklearn.preprocessing import LabelEncoder
cat=[i for i in df.columns if df[i].dtypes=='O']
enc = LabelEncoder()
for i in cat:
    df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               9551 non-null   int32
#  1   Restaurant Name       9551 non-null   int32
#  2   City                  9551 non-null   int32
#  3   Locality              9551 non-null   int32
#  4   Longitude             9551 non-null   float64
#  5   Latitude              9551 non-null   float64
#  6   Cuisines              9551 non-null   int32
#  7   Average Cost for two  9551 non-null   int64
#  8   Currency              9551 non-null   int32
#  9   Has Table booking     9551 non-null   int32
#  10  Has Online delivery   9551 non-null   int32
#  11  Price range           9551 non-null   int64
#  12  Aggregate rating      9551 non-null   float64
#  13  Rating color          9551 non-null   int32
#  14  Rating text           9551 non-null   int32
#  15  Votes                 9551 non-null   int64
# dtypes: float64(3), int32(10), int64(3)
# memory usage: 895.4 KB

# %%
# Cuisines missing values are filled with mode
df['Cuisines']=df['Cuisines'].fillna(df["Cuisines"].mode()[0])

# %%
df.isna().sum()
# Out:
# Country                 0
# Restaurant Name         0
# City                    0
# Locality                0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# ## Correlation

# %%
df.corr()
# Out:
#                        Country  Restaurant Name      City  Locality  \
# Country               1.000000         0.017560 -0.180959 -0.118784
# Restaurant Name       0.017560         1.000000 -0.001399  0.004322
# City                 -0.180959        -0.001399  1.000000  0.096444
# Locality             -0.118784         0.004322  0.096444  1.000000
# Longitude            -0.766221        -0.001920  0.117391  0.086448
# Latitude              0.181299         0.009922 -0.004301 -0.020424
# Cuisines             -0.124141         0.051496  0.025764  0.006499
# Average Cost for two -0.004034         0.019241 -0.028838 -0.012136
# Currency             -0.105296         0.009669 -0.071996  0.023723
# Has Table booking    -0.062076         0.041173 -0.003762 -0.065594
# Has Online delivery  -0.140464         0.028082  0.012723 -0.030993
# Price range           0.178035         0.061275 -0.105759 -0.114459
# Aggregate rating      0.255591         0.029367 -0.132163 -0.174336
# Rating color         -0.155486        -0.007311  0.110887  0.036831
# Rating text           0.203846         0.012131 -0.098985 -0.036969
# Votes                 0.155161         0.018512 -0.078406 -0.123569
#
#                       Longitude  Latitude  Cuisines  Average Cost for two  \
# Country               -0.766221  0.181299 -0.124141             -0.004034
# Restaurant Name       -0.001920  0.009922  0.051496              0.019241
# City                   0.117391 -0.004301  0.025764             -0.028838
# Locality               0.086448 -0.020424  0.006499             -0.012136
# Longitude              1.000000  0.043207  0.122457              0.045891
# Latitude               0.043207  1.000000  0.038646             -0.111088
# Cuisines               0.122457  0.038646  1.000000              0.005755
# Average Cost for two   0.045891 -0.111088  0.005755              1.000000
# Currency               0.337334 -0.101864  0.066783              0.045615
# Has Table booking      0.100488  0.054658  0.050232              0.007758
# Has Online delivery    0.178757  0.118722 -0.017180             -0.018974
# Price range           -0.078939 -0.166688 -0.005489              0.075083
# Aggregate rating      -0.116818  0.000516 -0.079494              0.051792
# Rating color           0.059979  0.042590 -0.016180             -0.049970
# Rating text           -0.181466 -0.129447 -0.080025              0.031439
# Votes                 -0.085101 -0.022962 -0.032362              0.067783
#
#                       Currency  Has Table booking  Has Online delivery  \
# Country              -0.105296          -0.062076            -0.140464
# Restaurant Name       0.009669           0.041173             0.028082
# City                 -0.071996          -0.003762             0.012723
# Locality              0.023723          -0.065594            -0.030993
# Longitude             0.337334           0.100488             0.178757
# Latitude             -0.101864           0.054658             0.118722
# Cuisines              0.066783           0.050232            -0.017180
# Average Cost for two  0.045615           0.007758            -0.018974
# Currency              1.000000           0.000640             0.006991
# Has Table booking     0.000640           1.000000             0.101224
# Has Online delivery   0.006991           0.101224             1.000000
# Price range           0.075179           0.501925             0.077918
# Aggregate rating     -0.006939           0.189998             0.225699
# Rating color         -0.040430          -0.021365             0.011477
# Rating text           0.014598           0.044043            -0.080937
# Votes                -0.027111           0.169422             0.074303
#
#                       Price range  Aggregate rating  Rating color  \
# Country                  0.178035          0.255591     -0.155486
# Restaurant Name          0.061275          0.029367     -0.007311
# City                    -0.105759         -0.132163      0.110887
# Locality                -0.114459         -0.174336      0.036831
# Longitude               -0.078939         -0.116818      0.059979
# Latitude                -0.166688          0.000516      0.042590
# Cuisines                -0.005489         -0.079494     -0.016180
# Average Cost for two     0.075083          0.051792     -0.049970
# Currency                 0.075179         -0.006939     -0.040430
# Has Table booking        0.501925          0.189998     -0.021365
# Has Online delivery      0.077918          0.225699      0.011477
# Price range              1.000000          0.437944     -0.140468
# Aggregate rating         0.437944          1.000000     -0.367054
# Rating color            -0.140468         -0.367054      1.000000
# Rating text              0.164242         -0.182662      0.163717
# Votes                    0.309444          0.313691     -0.169044
#
#                       Rating text     Votes
# Country                  0.203846  0.155161
# Restaurant Name          0.012131  0.018512
# City                    -0.098985 -0.078406
# Locality                -0.036969 -0.123569
# Longitude               -0.181466 -0.085101
# Latitude                -0.129447 -0.022962
# Cuisines                -0.080025 -0.032362
# Average Cost for two     0.031439  0.067783
# Currency                 0.014598 -0.027111
# Has Table booking        0.044043  0.169422
# Has Online delivery     -0.080937  0.074303
# Price range              0.164242  0.309444
# Aggregate rating        -0.182662  0.313691
# Rating color             0.163717 -0.169044
# Rating text              1.000000  0.203969
# Votes                    0.203969  1.000000

# %%
# let's check the correation with Price range
df.corr()['Price range'].sort_values()
# Out:
# Latitude               -0.166688
# Rating color           -0.140468
# Locality               -0.114459
# City                   -0.105759
# Longitude              -0.078939
# Cuisines               -0.005489
# Restaurant Name         0.061275
# Average Cost for two    0.075083
# Currency                0.075179
# Has Online delivery     0.077918
# Rating text             0.164242
# Country                 0.178035
# Votes                   0.309444
# Aggregate rating        0.437944
# Has Table booking       0.501925
# Price range             1.000000
# Name: Price range, dtype: float64

# %%
# let's check the correation with Average Cost for two
df.corr()['Average Cost for two'].sort_values()
# Out:
# Latitude               -0.111088
# Rating color           -0.049970
# City                   -0.028838
# Has Online delivery    -0.018974
# Locality               -0.012136
# Country                -0.004034
# Cuisines                0.005755
# Has Table booking       0.007758
# Restaurant Name         0.019241
# Rating text             0.031439
# Currency                0.045615
# Longitude               0.045891
# Aggregate rating        0.051792
# Votes                   0.067783
# Price range             0.075083
# Average Cost for two    1.000000
# Name: Average Cost for two, dtype: float64

# %%
# let's check correlation using heatmap
plt.figure(figsize=(22,15))
sns.heatmap(df.corr(),annot =True,fmt  = '.0%')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Obserrvations:-
# - City,Locality,longitude,latitude,Cuisines and Rating color  are negatively correlated with target.
# - Country,Restaurant Name,average cost for two,currency,has table booking,has online delivery,aggregate rating,rating text and   votes are positively correlated with target variable
# - maximum correlation : Has table booking
# - minimum correlation : restaurant name

# %%
df.drop(columns = ['Longitude'],inplace =True)
df.drop(columns=['Currency'],inplace =True)

# %%
df.shape
# Out:
# (9551, 14)

# %% [markdown]
# ## Normal Distribution curve for every individual column

# %%
# let's visualize the data using distribution plot
plt.figure(figsize=(32,38))
pn = 1
for col in df:
    if pn <= 15:
        ax = plt.subplot(4,4,pn)
        sns.distplot(df[col])
        plt.xlabel(col,fontsize = 15)
        plt.ylabel('Average Cost for two',fontsize = 15)
    pn +=1
plt.show()

# %% [markdown]
# ### Votes, Average Cost for two and latitude features are indicating the presence of outliers.skewness is also present

# %% [markdown]
# ### Checking Outliers

# %%
plt.figure(figsize=(25,15))
pn = 1
for col in df:
    if pn <=15:
        ax = plt.subplot(3,5,pn)
        sns.boxplot(data=df[col])
        plt.xlabel(col,fontsize = 15)
    pn +=1
plt.show()

# %% [markdown]
# ### as per my observation, Votes, Average Cost for two and latitude features are indicating the presence of outliers. we will remove the outliers by using zscore technique

# %% [markdown]
# ## Removing Outliers

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)

df=df1.copy()
# Out:
# Shape of the dataframe before removing outliers:  (9551, 14)
# Shape of the dataframe after removing outliers:  (8522, 14)
# Percentage of data loss post outlier removal:  10.773740969531985

# %% [markdown]
# ## Skewness

# %%
df.skew()
# Out:
# Country                 10.733251
# Restaurant Name          0.045394
# City                    -1.273778
# Locality                -0.312748
# Latitude                -3.104168
# Cuisines                -0.343686
# Average Cost for two     3.689251
# Has Table booking        2.266970
# Has Online delivery      0.999797
# Price range              1.035467
# Aggregate rating        -0.869124
# Rating color             0.090938
# Rating text              0.429728
# Votes                    3.646786
# dtype: float64

# %% [markdown]
# ## Dividing data in features and label

# %%
x = df.drop('Average Cost for two',axis = 1)
x.head()
# Out:
#     Country  Restaurant Name  City  Locality   Latitude  Cuisines  \
# 82        3             3585    11        19  19.876219      1338
# 83        3              617    11       187   0.000000      1049
# 84        3              354    11       150  19.874733      1329
# 85        3             2099    11       150  19.876106      1618
# 86        3             3010    11       150  19.875522      1554
#
#     Has Table booking  Has Online delivery  Price range  Aggregate rating  \
# 82                  0                    0            3               3.6
# 83                  0                    0            3               3.3
# 84                  0                    0            2               3.3
# 85                  0                    0            2               3.1
# 86                  0                    0            2               3.4
#
#     Rating color  Rating text  Votes
# 82             5            2    240
# 83             2            0     65
# 84             2            0     63
# 85             2            0     19
# 86             2            0     46

# %%
y=df['Average Cost for two']

# %% [markdown]
# ### Removal of skewness using Power Transformer as values are negative we are using 'yeo-johnson' method for removing skewness

# %%
from sklearn.preprocessing import PowerTransformer
p_transform = PowerTransformer(method = 'yeo-johnson')
x = pd.DataFrame(p_transform.fit_transform(x), columns=x.columns)
x.head(10)
# Out:
#     Country  Restaurant Name      City  Locality  Latitude  Cuisines  \
# 0 -0.065453         0.086893 -2.367235 -2.127897 -1.864193  0.655127
# 1 -0.065453        -1.527412 -2.367235 -1.589608 -3.057099  0.089655
# 2 -0.065453        -1.747552 -2.367235 -1.709051 -1.864445  0.637596
# 3 -0.065453        -0.618770 -2.367235 -1.709051 -1.864212  1.198340
# 4 -0.065453        -0.172300 -2.367235 -1.709051 -1.864311  1.074531
# 5 -0.065453        -0.115149 -2.367235 -1.709051 -1.864493  1.404903
# 6 -0.065453         0.231711 -2.367235 -1.709051 -1.864246  0.659022
# 7 -0.065453         0.293994 -2.367235 -1.709051 -1.864158  0.123075
# 8 -0.065453         0.447246 -2.367235 -1.709051 -1.864552  0.592774
# 9 -0.065453         1.570666 -2.367235 -0.802986 -1.864343 -0.695863
#
#    Has Table booking  Has Online delivery  Price range  Aggregate rating  \
# 0          -0.378117            -0.618139     1.386722          0.754636
# 1          -0.378117            -0.618139     1.386722          0.482227
# 2          -0.378117            -0.618139     0.701409          0.482227
# 3          -0.378117            -0.618139     0.701409          0.307627
# 4          -0.378117            -0.618139     0.701409          0.571639
# 5          -0.378117            -0.618139     0.701409          0.571639
# 6          -0.378117            -0.618139     1.744182          0.571639
# 7          -0.378117            -0.618139     0.701409          0.482227
# 8          -0.378117            -0.618139     0.701409          0.571639
# 9          -0.378117            -0.618139     1.386722          0.754636
#
#    Rating color  Rating text     Votes
# 0      1.340388     0.485462  1.266091
# 1     -0.727260    -1.101710  0.578158
# 2     -0.727260    -1.101710  0.561945
# 3     -0.727260    -1.101710 -0.046440
# 4     -0.727260    -1.101710  0.399618
# 5     -0.727260    -1.101710  0.652567
# 6     -0.727260    -1.101710  0.770521
# 7     -0.727260    -1.101710  0.410668
# 8     -0.727260    -1.101710  0.624035
# 9      1.340388     0.485462  0.638492

# %%
pd.DataFrame(x).skew().sort_values()
# Out:
# Country               -9.894367
# Latitude              -0.783158
# Aggregate rating      -0.626987
# Cuisines              -0.369714
# Locality              -0.302800
# Restaurant Name       -0.272152
# Rating color          -0.077029
# Rating text           -0.031030
# Votes                 -0.007535
# City                   0.187035
# Price range            0.242351
# Has Online delivery    0.999797
# Has Table booking      2.266970
# dtype: float64

# %% [markdown]
# ### Every value will be reduced after transformation

# %%
# data scaling formula z = (x-mean)/std
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled= scaler.fit_transform(x)
x_scaled
# Out:
# array([[-0.06545344,  0.08689312, -2.36723508, ...,  1.34038821,
#          0.48546163,  1.26609143],
#        [-0.06545344, -1.52741166, -2.36723508, ..., -0.72726043,
#         -1.1017105 ,  0.57815826],
#        [-0.06545344, -1.7475517 , -2.36723508, ..., -0.72726043,
#         -1.1017105 ,  0.56194547],
#        ...,
#        [ 7.05589129, -0.14501514,  5.73321055, ...,  1.34038821,
#          0.48546163,  1.81042658],
#        [ 7.05589129, -1.60994763,  5.73321055, ..., -1.57668876,
#          1.56184394,  1.97841952],
#        [ 7.05589129,  1.50338841,  5.73321055, ..., -1.57668876,
#          1.56184394,  1.74989149]])

# %% [markdown]
# ## Final features Multi-Collinearity Check using VIF**

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["Features List"]=x.columns
vif_data["VIF Value"]=[variance_inflation_factor(x.values, i)
                          for i in range(len(x.columns))]
vif_data
# Out:
#           Features List  VIF Value
# 0               Country   1.094193
# 1       Restaurant Name   1.008852
# 2                  City   1.020954
# 3              Locality   1.041010
# 4              Latitude   1.142968
# 5              Cuisines   1.028137
# 6     Has Table booking   1.365470
# 7   Has Online delivery   1.210120
# 8           Price range   1.725756
# 9      Aggregate rating   4.751397
# 10         Rating color   1.405404
# 11          Rating text   1.469666
# 12                Votes   4.989191

# %% [markdown]
# ### There is no sign of Multi-collinearity

# %%
# let's visualize the data after correcting skewness
plt.figure(figsize=(18,20))
plotnumber=1
for column in x:
    if plotnumber<=16:
        plt.subplot(4,4,plotnumber)
        ax=sns.distplot(x[column])
        
    plotnumber+=1
    
plt.show()

# %% [markdown]
# ### Skewness has been corrected and data is distributed normally. Now ,our model is ready for model building

# %% [markdown]
# # Model selection/predictions

# %% [markdown]
# ## Regression because our Target variable 'Average Cost for two' is continuous.

# %% [markdown]
# ### Finding the best Random state and maximum accuracy

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
maxAccu=0
maxRS=0

for i in range(1,500):
    X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.20, random_state=i)
    knn=KNeighborsRegressor()
    knn.fit(X_train, Y_train)
    pred = knn.predict(X_test)
    r2 = r2_score(Y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best r2 score is 0.7177299117061648 on Random State 364

# %% [markdown]
# **Splitting the data into Training and Testing**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.20, random_state=241)

# %% [markdown]
# **I am defining a function for splitting of the Training and Testing features alongwith Target, then it trains the model soon after training it predicts the Target and calculates RMSE score with R2 score alongwith this it calculates the Cross Validation score and finally it finds the difference between the R2 score and Cross Validation score.**

# %%
# Regression Model Function

def reg(model, x, y):
    X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.20, random_state=305)
    
    #Training the model
    model.fit(X_train, Y_train)
    
    #Predicting Y_test
    pred = model.predict(X_test)
    
    #RMSE
    rmse = mean_squared_error(Y_test, pred, squared=False)
    print("RMSE Score is:", rmse)
    
    #R2 score
    r2 = r2_score(Y_test, pred, multioutput='variance_weighted')*100
    print("R2 Score is:", r2)
    
    #CV Score
    cv_score = (cross_val_score(model, x, y, cv=5).mean())*100
    print("Cross Validation Score:", cv_score)
    
    #Difference
    result = r2 - cv_score
    print("R2 Score - Cross Validation Score is", result)

# %% [markdown]
# ## Linear Regression

# %%
#Linear regression
model=LinearRegression()
reg(model, x, y)
# Out:
# RMSE Score is: 332.8700209087166
# R2 Score is: 66.7083356904593
# Cross Validation Score: 51.52299626055138
# R2 Score - Cross Validation Score is 15.185339429907913

# %% [markdown]
# **Ridge Regression**

# %%
# Ridge Regression

model=Ridge(alpha=1e-2, normalize=True)
reg(model, x, y)
# Out:
# RMSE Score is: 332.7964558847426
# R2 Score is: 66.72304912994443
# Cross Validation Score: 51.80974469485847
# R2 Score - Cross Validation Score is 14.913304435085955

# %% [markdown]
# ## Decision Tree Regressor

# %%
# Decision Tree Regressor
model=DecisionTreeRegressor()
reg(model, x, y)
# Out:
# RMSE Score is: 230.9331446589094
# R2 Score is: 85.31788608328401
# Cross Validation Score: 46.36105929196334
# R2 Score - Cross Validation Score is 38.956826791320665

# %% [markdown]
# ## Random Forest Regressor

# %%
# Random Forest Regressor

model=RandomForestRegressor(max_depth=2, max_features="sqrt")
reg(model, x, y)
# Out:
# RMSE Score is: 406.19796716667196
# R2 Score is: 54.575355021740116
# Cross Validation Score: 52.11400596838256
# R2 Score - Cross Validation Score is 2.4613490533575586

# %% [markdown]
# ## KNeighbors Regressor

# %%
# K Neighbors Regressor

KNeighborsRegressor(n_neighbors=2, algorithm='kd_tree')
reg(model,x,y)
# Out:
# RMSE Score is: 387.01180217187044
# R2 Score is: 55.81031088688064
# Cross Validation Score: 53.982150266616955
# R2 Score - Cross Validation Score is 1.828160620263688

# %% [markdown]
# ## Support Vector Regression

# %%
# Support Vector Regression

model=SVR(C=1.0, epsilon=0.2, kernel='poly', gamma='auto')
reg(model, x, y)
# Out:
# RMSE Score is: 437.8937112407761
# R2 Score is: 38.039427035096566
# Cross Validation Score: 34.121167617980795
# R2 Score - Cross Validation Score is 3.9182594171157703

# %% [markdown]
#  ###  as per my observation , I choose Random Forest as the best model and model accuracy and cross val score difference  is also least.

# %% [markdown]
# ## HYPERPARAMETER TUNING

# %%
rf=RandomForestRegressor()

# %%
params = {'n_jobs':[20],
         'warm_start':[True,False],
         'oob_score':[True,False],
         'min_samples_split':[2,5],
         'min_samples_leaf':[2,4],
         'criterion':['squared_error'],
         'max_leaf_nodes':[5]}

# %%
grd = GridSearchCV(rf,param_grid = params)
grd.fit(X_train,Y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['squared_error'], 'max_leaf_nodes': [5],
#                          'min_samples_leaf': [2, 4],
#                          'min_samples_split': [2, 5], 'n_jobs': [20],
#                          'oob_score': [True, False],
#                          'warm_start': [True, False]})

# %%
rf = grd.best_estimator_
rf.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(max_leaf_nodes=5, min_samples_leaf=2, min_samples_split=5,
#                       n_jobs=20, warm_start=True)

# %%
pred = rf.predict(X_test)
r2_score(Y_test,pred)*100
# Out:
# 76.17877700923489

# %% [markdown]
# # save the final model

# %%
import joblib
joblib.dump(rf,'Zomato.pkl')
# Out:
# ['Zomato.pkl']

# %% [markdown]
# # Model selection/predictions

# %% [markdown]
# ## Classification because our Target variable 'Price range' is categorical.

# %%
### Dividing data in features and label
x1 = df.drop('Price range',axis = 1)
x1.head()
# Out:
#     Country  Restaurant Name  City  Locality   Latitude  Cuisines  \
# 82        3             3585    11        19  19.876219      1338
# 83        3              617    11       187   0.000000      1049
# 84        3              354    11       150  19.874733      1329
# 85        3             2099    11       150  19.876106      1618
# 86        3             3010    11       150  19.875522      1554
#
#     Average Cost for two  Has Table booking  Has Online delivery  \
# 82                   800                  0                    0
# 83                   850                  0                    0
# 84                   600                  0                    0
# 85                   700                  0                    0
# 86                   350                  0                    0
#
#     Aggregate rating  Rating color  Rating text  Votes
# 82               3.6             5            2    240
# 83               3.3             2            0     65
# 84               3.3             2            0     63
# 85               3.1             2            0     19
# 86               3.4             2            0     46

# %%
y1=df['Price range']

# %% [markdown]
# ## Best Random State

# %%
# lets import all necessary libraries 
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix,classification_report,roc_curve,roc_auc_score,accuracy_score

# %%
maxAccu=0
maxRS=0

for i in range(1, 500):
    X_train, X_test, Y_train, Y_test = train_test_split(x1, y1, test_size=0.20, random_state=i)
    knn=KNeighborsClassifier()
    knn.fit(X_train, Y_train)
    pred = knn.predict(X_test)
    acc = accuracy_score(Y_test, pred)
    
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i

print("Best accuracy score is", maxAccu,"on Random State", maxRS)
# Out:
# Best accuracy score is 0.9090909090909091 on Random State 455

# %%
# create empty lits
accur_score=[]
c_v_score=[]
diff=[]

# %%
x_train,x_test,y_train,y_test = train_test_split(x1,y1,test_size= 0.20,random_state = 218)

# %%
# classification model Function
def classify(model,x1,y1):
    x_train,x_test,y_train,y_test = train_test_split(x1,y1,test_size= 0.20,random_state = 218)
    # training the model
    model.fit(x_train,y_train)
    
    # predicting y_test
    pred = model.predict(x_test)
    
    # Accuracy score
    acc_score=(accuracy_score(y_test,pred))*100
    accur_score.append(acc_score)
    print('Accuracy score',acc_score)
    
    # Classification report
    class_report=classification_report(y_test,pred)
    print('\nClassification Report:\n',class_report)
    
    # Cross validation score
    cv_score=(cross_val_score(model,x1,y1,cv=15).mean())*100
    c_v_score.append(cv_score)
    print('Cross validation score',cv_score)
    
    # result of accuracy score minus cv_score
    result = acc_score-cv_score
    diff.append(result)
    print('\n Accuracy score - cross val score is:',result)

     # Confusion_matrix
    plt.figure(figsize=(4,3))
    print("\n\n",sns.heatmap(confusion_matrix(y_test,pred),annot=True,fmt = "d",linecolor="k",linewidths=3))
    plt.title("CONFUSION MATRIX",fontsize=14)
    plt.show()

# %% [markdown]
# ## KNN

# %%
model = KNeighborsClassifier()
classify(model,x1,y1)
# Out:
# Accuracy score 90.9090909090909
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.94      0.96      0.95       911
#            2       0.88      0.89      0.89       521
#            3       0.87      0.81      0.84       202
#            4       0.90      0.63      0.74        71
#
#     accuracy                           0.91      1705
#    macro avg       0.90      0.82      0.85      1705
# weighted avg       0.91      0.91      0.91      1705
#
# Cross validation score 87.66776405356568
#
#  Accuracy score - cross val score is: 3.24132685552523
#
#
#  AxesSubplot(0.125,0.125;0.62x0.755)

# %% [markdown]
# ### After setting the random state = 455 , We got the accuracy score is 90%

# %% [markdown]
# ## Random Forest

# %%
model =RandomForestClassifier()
classify(model,x1,y1)
# Out:
# Accuracy score 98.53372434017595
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      0.99      0.99       841
#            2       0.98      0.99      0.98       558
#            3       0.97      0.96      0.96       225
#            4       0.97      0.93      0.95        81
#
#     accuracy                           0.99      1705
#    macro avg       0.98      0.97      0.97      1705
# weighted avg       0.99      0.99      0.99      1705
#
# Cross validation score 96.6678218107709
#
#  Accuracy score - cross val score is: 1.865902529405048
#
#
#  AxesSubplot(0.125,0.125;0.62x0.755)

# %% [markdown]
# ### After setting the random state = 218 , We got the accuracy score is 98%

# %% [markdown]
# ## AdaBoost

# %%
model=AdaBoostClassifier()
classify(model,x1,y1)
# Out:
# Accuracy score 85.63049853372434
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00       876
#            2       0.71      0.98      0.83       586
#            3       0.25      0.01      0.01       163
#            4       0.58      0.09      0.15        80
#
#     accuracy                           0.86      1705
#    macro avg       0.64      0.52      0.50      1705
# weighted avg       0.81      0.86      0.80      1705
#
# Cross validation score 82.78602193123592
#
#  Accuracy score - cross val score is: 2.844476602488413
#
#
#  AxesSubplot(0.125,0.125;0.62x0.755)

# %% [markdown]
# ### After setting the random state = 469, We got the accuracy score is 85%

# %% [markdown]
# ## Decision tree

# %%
model=DecisionTreeClassifier()
classify(model,x1,y1)
# Out:
# Accuracy score 99.29618768328446
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       846
#            2       0.99      0.99      0.99       580
#            3       0.99      0.97      0.98       203
#            4       0.95      0.99      0.97        76
#
#     accuracy                           0.99      1705
#    macro avg       0.98      0.99      0.98      1705
# weighted avg       0.99      0.99      0.99      1705
#
# Cross validation score 96.24551350280946
#
#  Accuracy score - cross val score is: 3.0506741804749993
#
#
#  AxesSubplot(0.125,0.125;0.62x0.755)

# %% [markdown]
# ### After setting the random state = 209 , We got the accuracy score is 99%

# %% [markdown]
# ## Compare the models

# %%
# create a list of labels of build models
label = ['Random Forest','AdaBoost','Decision Tree','KNN']
print(label)
print(accur_score)
print(c_v_score)
print(diff)
# Out:
# ['Random Forest', 'AdaBoost', 'Decision Tree', 'KNN']
# [98.82697947214076, 85.63049853372434, 99.29618768328446, 90.9090909090909]
# [96.60911573718823, 82.78602193123592, 96.24551350280946, 87.66776405356568]
# [2.2178637349525303, 2.844476602488413, 3.0506741804749993, 3.24132685552523]

# %%
# create dataframe
score_df = pd.DataFrame({'Model name':label,'Accuracy Score':accur_score,'Cross validation Score':c_v_score,'Difference':diff})
score_df
# Out:
#       Model name  Accuracy Score  Cross validation Score  Difference
# 0  Random Forest       98.826979               96.609116    2.217864
# 1       AdaBoost       85.630499               82.786022    2.844477
# 2  Decision Tree       99.296188               96.245514    3.050674
# 3            KNN       90.909091               87.667764    3.241327

# %% [markdown]
#  ###  as per my observation , I choose Random Forest as the best model and model accuracy and cross val score difference  is also least.

# %% [markdown]
# # Save the final model

# %%
import joblib
joblib.dump(rf,'Zomato.pkl')
# Out:
# ['Zomato.pkl']
