# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('HR Analytics.csv')
df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %% [markdown]
# ## Observations:-
# Firstly, we explore the HR Analytics dataset
# - Features of dataset
# - 'Age' : It shows the age of employees.
# - 'BusinessTravel': It has three type of values and datatype is object.we will handle the column using encoding technique
# - 'Department': It has three values 'Sales' 'Research & Development' 'Human Resources' and datatype is object.
# - 'EducationField: It has five values 'Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree' and datatype is object.
# - 'EmployeeNumber': no need of this column , it has only emp id  numbers
# - 'Gender': it shows the gender of employees.
# - 'JobRole': It shows the job role 'Sales Executive' ,'Research Scientist', 'Laboratory Technician','Manufacturing Director'                    'Healthcare Representative','Manager','Sales Representative', 'Research Director' ,'Human Resources'
# - 'MaritalStatus': It shows the maritalStatus.
# - 'MonthlyIncome': It shows the monthly income of employees
# - 'Over18': it has single value there is no use of this column
# - 'OverTime': It shows the overtime of employees
# - 'PercentSalaryHike': it shows the salary hike of employees.
# - 'PerformanceRating': it shows the performance
# - 'StandardHours': it has single value
# - 'TotalWorkingYears': it shows the working years of employees.
#
# - 'Attrition': this is our target variable,it shows the number of employees that stayed and left in company

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows", None)

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# ### we have 1470 rows and 35 columns

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
##Checking Data type of features and label
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ### Attrition,BusinessTravel,Over18,OverTime,MaritalStatus,JobRole,Gender,EducationField,Department features are having object type values .we will use encoding techniques to handles this situation.

# %%
# let's check the missing values of a dataset
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ### There is no null values present in this dataset

# %%
# let's check the duplicate rows present or not in this dataset
duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []

# %% [markdown]
# ### There is no duplicates present in this dataset

# %%
df['Attrition']=df['Attrition'].replace({'Yes':1,'No':0})
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
# print all the datatypes and unique values
for column in df.columns:
    if df[column].dtype== object:
        print(str(column) + ':' + str(df[column].unique()))
        print(df[column].value_counts())
        print('---------------------------------------------------------------------------------')
# Out:
# BusinessTravel:['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# ---------------------------------------------------------------------------------
# Department:['Sales' 'Research & Development' 'Human Resources']
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# ---------------------------------------------------------------------------------
# EducationField:['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# ---------------------------------------------------------------------------------
# Gender:['Female' 'Male']
# Male      882
# Female    588
# ...

# %%
# let's drop the unnecessary columns from dataset
df.drop(columns = ['EmployeeCount'],axis = 1,inplace= True)
df.drop(columns = ['EmployeeNumber'],axis = 1,inplace= True)
df.drop(columns = ['StandardHours'],axis = 1,inplace= True)
df.drop(columns = ['Over18'],axis = 1,inplace= True)
df.shape
# Out:
# (1470, 31)

# %%
# stats about data
df.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.161224   802.485714          9.192517     2.912925
# std       9.135373     0.367863   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.000000          2.000000     2.000000
# 50%      36.000000     0.000000   802.000000          7.000000     3.000000
# 75%      43.000000     0.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# ...

# %%
df.describe()
plt.figure(figsize=(20,18))
sns.heatmap(round(df.describe()[1:].transpose(),2),annot=True,fmt='f',cmap='coolwarm')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("VARIABLES SUMMARY")
plt.show()

# %% [markdown]
# ## Observations:-
# - In variable summery MonthlyIncome and Monthly Rate indicating the presence of outliers
# - Age: Avg. age of employees are 36,minimum age is 18 and max age is 60.
# - Most of the features are having categorical type data

# %%
df.shape
# Out:
# (1470, 31)

# %% [markdown]
# # EDA

# %%
# let's visualize the Attrition
sns.countplot(df['Attrition'])
plt.show()

# %%
## count the number of employees that stayed and left the company 
df['Attrition'].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
(1233-237)/1233
# Out:
# 0.8077858880778589

# %% [markdown]
# ### 80% of employees are stayed

# %%
# shows the number of employees that stayed and left by age
plt.figure(figsize = (20,10))
sns.countplot(x='Age',hue = 'Attrition',data = df)
plt.show()
print('avrage age of employees are',df['Age'].mean())
# Out:
# avrage age of employees are 36.923809523809524

# %% [markdown]
# ###  34 and 35 age group employees those are stayed in company and 29 and 31 age group employees are left the company. average age is 36

# %%
#let's visualize the relationship between Attrition and BusinessTravel
plt.figure(figsize=(10,6))
sns.countplot(x=df['Attrition'],hue='BusinessTravel',data=df, palette = 'Accent').set_title("Number of Attritions Reported by Amount of Business Travel")
plt.show()

# %%
df.groupby('BusinessTravel')['Attrition'].value_counts()
# Out:
# BusinessTravel     Attrition
# Non-Travel         0            138
#                    1             12
# Travel_Frequently  0            208
#                    1             69
# Travel_Rarely      0            887
#                    1            156
# Name: Attrition, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['Attrition'],hue='Department',data=df, palette = 'Accent').set_title("Number of Attritions Reported by Amount of Department")
plt.show()

# %%
df.groupby('Department')['Attrition'].value_counts()
# Out:
# Department              Attrition
# Human Resources         0             51
#                         1             12
# Research & Development  0            828
#                         1            133
# Sales                   0            354
#                         1             92
# Name: Attrition, dtype: int64

# %% [markdown]
# ### Research and development department has more employees as compared to other departments

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['Attrition'],hue='EducationField',data=df, palette = 'Accent').set_title("Number of Attritions Reported by Amount of Education Field")
plt.show()

# %%
df.groupby('EducationField')['Attrition'].value_counts()
# Out:
# EducationField    Attrition
# Human Resources   0             20
#                   1              7
# Life Sciences     0            517
#                   1             89
# Marketing         0            124
#                   1             35
# Medical           0            401
#                   1             63
# Other             0             71
#                   1             11
# Technical Degree  0            100
#                   1             32
# Name: Attrition, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['Attrition'],hue='Gender',data=df, palette = 'Accent').set_title("Number of Attritions Reported by Gender")
plt.show()

# %%
df.groupby('Gender')['Attrition'].value_counts()
# Out:
# Gender  Attrition
# Female  0            501
#         1             87
# Male    0            732
#         1            150
# Name: Attrition, dtype: int64

# %% [markdown]
# ### As compared to female ,male employees are more

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['Attrition'],hue='JobRole',data=df, palette = 'Accent').set_title("Number of Attritions Reported by Job Role")
plt.show()

# %%
df.groupby('JobRole')['Attrition'].value_counts()
# Out:
# JobRole                    Attrition
# Healthcare Representative  0            122
#                            1              9
# Human Resources            0             40
#                            1             12
# Laboratory Technician      0            197
#                            1             62
# Manager                    0             97
#                            1              5
# Manufacturing Director     0            135
#                            1             10
# Research Director          0             78
#                            1              2
# Research Scientist         0            245
#                            1             47
# Sales Executive            0            269
#                            1             57
# Sales Representative       0             50
#                            1             33
# Name: Attrition, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['Attrition'],hue='MaritalStatus',data=df, palette = 'Accent').set_title("Number of Attritions Reported by Marital Status")
plt.show()

# %%
df.groupby('MaritalStatus')['Attrition'].value_counts()
# Out:
# MaritalStatus  Attrition
# Divorced       0            294
#                1             33
# Married        0            589
#                1             84
# Single         0            350
#                1            120
# Name: Attrition, dtype: int64

# %% [markdown]
# ### married employees are more than others

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['Attrition'],hue='OverTime',data=df, palette = 'Accent').set_title("Number of Attritions Reported by OverTime")
plt.show()

# %%
df.groupby('OverTime')['Attrition'].value_counts()
# Out:
# OverTime  Attrition
# No        0            944
#           1            110
# Yes       0            289
#           1            127
# Name: Attrition, dtype: int64

# %%
# converting text into numbers using label encoder
from sklearn.preprocessing import LabelEncoder
cat=[i for i in df.columns if df[i].dtypes=='O']
enc = LabelEncoder()
for i in cat:
    df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0          2               1                        2       0          94
# 1          1               1                        3       1          61
# 2          2               4                        4       1          92
# 3          4               1                        4       0          56
# 4          1               3                        1       1          40
#
# ...

# %%
# let's visualize the data using distribution plot
plt.figure(figsize=(32,38))
pn = 1
for col in df:
    if pn <= 31:
        ax = plt.subplot(8,4,pn)
        sns.distplot(df[col])
        plt.xlabel(col,fontsize = 15)
        plt.ylabel('Attrition',fontsize = 15)
    pn +=1
plt.show()

# %% [markdown]
# ### most of the features are having categorical values and data is normally distributed, some features are showing outliers

# %% [markdown]
# ### Checking Outliers

# %%
plt.figure(figsize=(25,35))
pn = 1
for col in df:
    if pn <= 31:
        ax = plt.subplot(8,4,pn)
        sns.boxplot(data=df[col])
        plt.xlabel(col,fontsize = 15)
    pn +=1
plt.show()

# %% [markdown]
# ### as per my observation, some columns are indicating the presence of outliers. we will remove the outliers by using zscore technique

# %% [markdown]
# ## Removing Outliers

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)

df=df1.copy()
# Out:
# Shape of the dataframe before removing outliers:  (1470, 31)
# Shape of the dataframe after removing outliers:  (1387, 31)
# Percentage of data loss post outlier removal:  5.646258503401361

# %% [markdown]
# ## Correlation

# %%
df.corr()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159366        0.022340   0.021946
# Attrition                -0.159366   1.000000       -0.001041  -0.057220
# BusinessTravel            0.022340  -0.001041        1.000000  -0.004606
# DailyRate                 0.021946  -0.057220       -0.004606   1.000000
# Department               -0.038242   0.063637       -0.003521  -0.005398
# DistanceFromHome         -0.011265   0.081788       -0.032873  -0.008171
# Education                 0.198502  -0.032703       -0.010560  -0.018442
# EducationField           -0.032676   0.023585        0.022576   0.040645
# EnvironmentSatisfaction   0.014098  -0.112393        0.001183   0.033123
# Gender                   -0.039430   0.036252       -0.025364  -0.005242
# HourlyRate                0.025465  -0.001532        0.025424   0.014279
# JobInvolvement            0.036424  -0.133957        0.028261   0.048004
# ...

# %%
# let's check the correation with Attrition
df.corr()['Attrition'].sort_values
# Out:
# <bound method Series.sort_values of Age                        -0.159366
# Attrition                   1.000000
# BusinessTravel             -0.001041
# DailyRate                  -0.057220
# Department                  0.063637
# DistanceFromHome            0.081788
# Education                  -0.032703
# EducationField              0.023585
# EnvironmentSatisfaction    -0.112393
# Gender                      0.036252
# HourlyRate                 -0.001532
# JobInvolvement             -0.133957
# JobLevel                   -0.171968
# JobRole                     0.064283
# JobSatisfaction            -0.114206
# MaritalStatus               0.160960
# MonthlyIncome              -0.161848
# MonthlyRate                 0.014888
# NumCompaniesWorked          0.050314
# OverTime                    0.257237
# PercentSalaryHike          -0.006267
# PerformanceRating           0.010781
# RelationshipSatisfaction   -0.052344
# StockOptionLevel           -0.136676
# ...

# %%
df.drop('Attrition',axis=1).corrwith(df.Attrition).plot(kind='bar',grid=True,figsize=(14,8))
plt.show()

# %%
# let's check correlation using heatmap
plt.figure(figsize=(22,15))
sns.heatmap(df.corr(),annot =True,fmt  = '.0%')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Obserrvations:-
# - Most of the features are negatively correlated with target.
# - Department,DistanceFromHome,EducationField,Gender,JobRole,MaritalStatus,MonthlyRate,NumCompaniesWorked,OverTime,               PerformanceRating are positively correlated with target variable
# - Multicollinearity problem exist in YearsWithCurrManager and YearsAtCompany.              .
# - Multicollinearity problem also exist in JobLevel and MonthlyIncome.              .
# - maximum correlation : OverTime
# - minimum correlation : PerformanceRating
# - JobLevel and MonthlyIncome are negatively correlated with Target variable and YearsWithCurrManager and YearsAtCompany are       negatively correlated with targetvariable. we have visualized the Multi-Collinearity problem in these features we are going     to drop these features.

# %%
# drop the unnecessary column those are having multicollinearity problem exist
df.drop(columns=['JobLevel','YearsAtCompany'],axis = 1,inplace = True)
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0          2               1                        2       0          94
# 1          1               1                        3       1          61
# 2          2               4                        4       1          92
# 3          4               1                        4       0          56
# 4          1               3                        1       1          40
#
# ...

# %%
df.shape
# Out:
# (1387, 29)

# %% [markdown]
# ## Dividing data in features and label

# %%
x = df.drop('Attrition',axis = 1)
x.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   41               2       1102           2                 1          2
# 1   49               1        279           1                 8          1
# 2   37               2       1373           1                 2          2
# 3   33               1       1392           1                 3          4
# 4   27               2        591           1                 2          1
#
#    EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0               1                        2       0          94
# 1               1                        3       1          61
# 2               4                        4       1          92
# 3               1                        4       0          56
# 4               3                        1       1          40
#
#    JobInvolvement  JobRole  JobSatisfaction  MaritalStatus  MonthlyIncome  \
# ...

# %%
y=df['Attrition']
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Attrition, dtype: int64

# %%
# data scaling formula z = (x-mean)/std
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled= scaler.fit_transform(x)
x_scaled
# Out:
# array([[ 0.5366811 ,  0.59312579,  0.73432467, ...,  0.04090327,
#         -0.71069889,  0.36826963],
#        [ 1.44211114, -0.90535412, -1.30776866, ...,  0.96589518,
#         -0.31047991,  0.9821999 ],
#        [ 0.08396607,  0.59312579,  1.40675151, ..., -1.19241928,
#         -0.71069889, -1.16655603],
#        ...,
#        [-1.04782149,  0.59312579, -1.61544736, ..., -0.575758  ,
#         -0.71069889, -0.24566063],
#        [ 1.44211114, -0.90535412,  0.53830356, ...,  0.65756454,
#         -0.71069889,  1.28916503],
#        [-0.2555702 ,  0.59312579, -0.44180199, ..., -0.26742737,
#         -0.31047991, -0.55262577]])

# %% [markdown]
# ## Applying PCA for removal of Curse of Dimensionality

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=28, svd_solver="full")
x = pd.DataFrame(pca.fit_transform(x), columns=x.columns)
x.head(2)
# Out:
#             Age  BusinessTravel   DailyRate  Department  DistanceFromHome  \
# 0   5168.608566     -239.678768 -305.408671  -28.063361          3.746372
# 1  10558.920102    -1322.905059  504.817570    4.061374         13.134224
#
#    Education  EducationField  EnvironmentSatisfaction    Gender  HourlyRate  \
# 0  -8.745624       -1.673139                -3.903847 -2.259624   -2.627226
# 1  -0.896210        1.229148                 8.314129 -5.314671   -0.890684
#
#    JobInvolvement   JobRole  JobSatisfaction  MaritalStatus  MonthlyIncome  \
# 0        4.666715 -3.217179         0.962499      -2.431494       1.714753
# 1       -1.492037 -2.409232        -0.034439      -0.525098      -0.449157
#
#    MonthlyRate  NumCompaniesWorked  OverTime  PercentSalaryHike  \
# 0     2.106492           -0.200079  0.320205          -1.891776
# 1    -1.744866           -0.342490 -0.230973           0.346748
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %% [markdown]
# ### Removal of skewness using Power Transformer as values are negative we are using 'yeo-johnson' method for same

# %%
from sklearn.preprocessing import PowerTransformer
p_transform = PowerTransformer(method = 'yeo-johnson')
x = pd.DataFrame(p_transform.fit_transform(x), columns=x.columns)
x.head(10)
# Out:
#         Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0  0.735903        0.427638  -0.757949   -1.392271          0.553322
# 1  1.488771       -0.051785   1.252046    0.209341          1.442015
# 2 -1.724648       -1.091620  -1.391821   -1.235864          0.623730
# 3  1.232206       -1.099481  -1.525611    0.523913          0.178904
# 4  0.323976       -0.690711   0.503715    1.281614         -0.622450
# 5 -0.355187       -0.793128  -0.506899   -0.608835          0.028282
# 6 -0.630907       -0.953011  -1.298445   -0.722726          2.548720
# 7 -0.146064       -1.009432  -1.398313   -0.012029         -0.681401
# 8 -0.760394        1.035140   1.517262    1.036400         -0.265154
# 9  0.326066        0.152324  -1.243457   -1.389159          0.409570
#
#    Education  EducationField  EnvironmentSatisfaction    Gender  HourlyRate  \
# 0  -1.456748       -0.241732                -1.316970 -0.675989   -1.140582
# ...

# %%
pd.DataFrame(x).skew().sort_values()
# Out:
# JobInvolvement             -0.110947
# WorkLifeBalance            -0.045055
# StockOptionLevel           -0.038163
# RelationshipSatisfaction   -0.031794
# PerformanceRating          -0.021897
# EducationField             -0.007663
# Gender                     -0.007098
# OverTime                   -0.000137
# Age                         0.007672
# MonthlyRate                 0.008998
# YearsWithCurrManager        0.009118
# DailyRate                   0.009639
# DistanceFromHome            0.010208
# YearsInCurrentRole          0.010209
# Department                  0.012402
# NumCompaniesWorked          0.013290
# JobSatisfaction             0.019693
# JobRole                     0.020025
# YearsSinceLastPromotion     0.030068
# PercentSalaryHike           0.034369
# MaritalStatus               0.035193
# MonthlyIncome               0.054385
# HourlyRate                  0.068686
# TotalWorkingYears           0.102173
# EnvironmentSatisfaction     0.117465
# ...

# %% [markdown]
# ### Every value will be reduced after transformation

# %% [markdown]
# ## Final features Multi-Collinearity Check using VIF**

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["Features List"]=x.columns
vif_data["VIF Value"]=[variance_inflation_factor(x.values, i)
                          for i in range(len(x.columns))]
vif_data
# Out:
#                Features List  VIF Value
# 0                        Age   1.001070
# 1             BusinessTravel   1.033973
# 2                  DailyRate   1.000387
# 3                 Department   1.001031
# 4           DistanceFromHome   1.004764
# 5                  Education   1.004121
# 6             EducationField   1.007605
# 7    EnvironmentSatisfaction   1.022238
# 8                     Gender   1.009164
# 9                 HourlyRate   1.004805
# 10            JobInvolvement   1.008663
# 11                   JobRole   1.009386
# 12           JobSatisfaction   1.000895
# 13             MaritalStatus   1.000954
# 14             MonthlyIncome   1.000666
# 15               MonthlyRate   1.001027
# 16        NumCompaniesWorked   1.000916
# 17                  OverTime   1.000230
# 18         PercentSalaryHike   1.003056
# 19         PerformanceRating   1.001535
# 20  RelationshipSatisfaction   1.031349
# 21          StockOptionLevel   1.000510
# ...

# %% [markdown]
# ### There is no sign of Multi-collinearity

# %%
# let's visualize the data after correcting skewness
plt.figure(figsize=(18,20))
plotnumber=1
for column in x:
    if plotnumber<=28:
        plt.subplot(6,5,plotnumber)
        ax=sns.distplot(x[column])
        
    plotnumber+=1
    
plt.show()

# %% [markdown]
# ### Skewness has been corrected and data is distributed normally

# %% [markdown]
# # Model Building

# %%
# lets import all necessary libraries 
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.metrics import confusion_matrix,classification_report,roc_curve,roc_auc_score,accuracy_score

# %% [markdown]
# ## Best Random State

# %%
# maximum accuracy
max_accu = 0
# best random state value for which max accuracy is achived
max_rs = 0
for i in range(1,300):
    x_train,x_test,y_train,y_test= train_test_split(x,y,test_size =0.20,random_state = i)
    lr = LogisticRegression()
    lr.fit(x_train,y_train)
    y_pred = lr.predict(x_train)
    score1 = accuracy_score(y_train,y_pred)
    pred = lr.predict(x_test)
    score=accuracy_score(y_test,pred)
    print('training score',score1,'testing score',score,'random state',i)
    if (score and score1) > max_accu:
        max_accu = score
        max_rs = i
        print('Training score',score1,'testing score',score,'random state',i)
# Out:
# training score 0.8782687105500451 testing score 0.8705035971223022 random state 1
# Training score 0.8782687105500451 testing score 0.8705035971223022 random state 1
# training score 0.8764652840396754 testing score 0.8669064748201439 random state 2
# Training score 0.8764652840396754 testing score 0.8669064748201439 random state 2
# training score 0.8800721370604148 testing score 0.8776978417266187 random state 3
# Training score 0.8800721370604148 testing score 0.8776978417266187 random state 3
# training score 0.8854824165915239 testing score 0.8525179856115108 random state 4
# Training score 0.8854824165915239 testing score 0.8525179856115108 random state 4
# training score 0.8917944093778178 testing score 0.8309352517985612 random state 5
# Training score 0.8917944093778178 testing score 0.8309352517985612 random state 5
# training score 0.8719567177637512 testing score 0.9136690647482014 random state 6
# ...

# %%
# create empty list
training_score = []
testing_score = []
cross_val = []

# %% [markdown]
# ## Train Test Split

# %%
#split data into train and test, model will be build on training data and tested on test data
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.20,random_state = 44)

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ## Model Building using KNN

# %%
# creating object for KNeighbors
knn = KNeighborsClassifier()
# model training
knn.fit(x_train,y_train)
# predict the training score
y_pred = knn.predict(x_train)
training_score_knn =accuracy_score(y_train,y_pred)*100 
training_score.append(training_score_knn)
print('Training score',training_score_knn)
pred = knn.predict(x_test)
testing_score_knn=accuracy_score(y_test,pred)*100
testing_score.append(testing_score_knn)
print('Testing score',testing_score_knn)
print(classification_report(y_test,pred))
# Out:
# Training score 86.83498647430116
# Testing score 86.6906474820144
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.93       235
#            1       0.75      0.21      0.33        43
#
#     accuracy                           0.87       278
#    macro avg       0.81      0.60      0.63       278
# weighted avg       0.85      0.87      0.83       278

# %%
# Create confusion matrix function
from sklearn.metrics import classification_report, confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Compute confusion matrix for testing data
cnf_matrix = confusion_matrix(y_test, pred, labels=[1,0])
# Plot confusion matrix
plot_confusion_matrix(cnf_matrix, classes=['Attrition=1','Attrition=0'],normalize= False,  title='Test Confusion matrix')

# %% [markdown]
# ### After setting the random state = 44 , We got the accuracy score is 86%

# %% [markdown]
# ##  Cross validation for KNN

# %%
cr1 = cross_val_score(knn,x,y,cv =17)*100
cross_val_knn = cr1.mean()
cross_val.append(cross_val_knn)
print("Cross validation score of KNN is: ",cross_val_knn)
# Out:
# Cross validation score of KNN is:  83.7052978372921

# %% [markdown]
# ### Difference between model accuracy and cross validation accuracy score is 3

# %% [markdown]
# ## Model Building using Random Forest

# %%
#split data into train and test, model will be build on training data and tested on test data
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.20,random_state = 48)

# %%
# creating object for RandomForest
rf = RandomForestClassifier()
# model training
rf.fit(x_train,y_train)
# predict the training score
y_pred = rf.predict(x_train)
training_score_rf = accuracy_score(y_train,y_pred)*100
training_score.append(training_score_rf)
print('Training score',training_score_rf)
pred = rf.predict(x_test)
testing_score_rf = accuracy_score(y_test,pred)*100
testing_score.append(testing_score_rf)
print('Testing score',testing_score_rf)
print(classification_report(y_test,pred))
# Out:
# Training score 100.0
# Testing score 90.28776978417267
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95       247
#            1       1.00      0.13      0.23        31
#
#     accuracy                           0.90       278
#    macro avg       0.95      0.56      0.59       278
# weighted avg       0.91      0.90      0.87       278

# %%
# Compute confusion matrix for testing data
cnf_matrix = confusion_matrix(y_test, pred, labels=[1,0])
# Plot confusion matrix
plot_confusion_matrix(cnf_matrix, classes=['Attrition=1','Attrition=0'],normalize= False,  title='Test Confusion matrix')

# %% [markdown]
# ### After setting the random state = 48, We got the accuracy score is 90%

# %% [markdown]
# ## Cross validation for Random Forest

# %%
cr2 = cross_val_score(rf,x,y,cv = 17)*100
cross_val_knn = cr2.mean()
cross_val.append(cross_val_knn)
print("Cross validation score of Random Forest model",cross_val_knn)
# Out:
# Cross validation score of Random Forest model 84.86104468887825

# %% [markdown]
# ### Difference between model accuracy and cross validation accuracy score is 6

# %% [markdown]
# ## Model Building using Decision tree

# %%
#split data into train and test, model will be build on training data and tested on test data
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.20,random_state = 170)

# %%
# creating object for DecisionTree
dt = DecisionTreeClassifier()
# model training
dt.fit(x_train,y_train)
# predict the training score
y_pred = dt.predict(x_train)
training_score_dt =accuracy_score(y_train,y_pred)*100 
training_score.append(training_score_dt)
print('Training score',training_score_dt)
pred = dt.predict(x_test)
testing_score_dt =accuracy_score(y_test,pred)*100 
testing_score.append(testing_score_dt)
print('Testing score',testing_score_dt)
print(classification_report(y_test,pred))
# Out:
# Training score 100.0
# Testing score 83.81294964028777
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91       242
#            1       0.35      0.31      0.33        36
#
#     accuracy                           0.84       278
#    macro avg       0.63      0.61      0.62       278
# weighted avg       0.83      0.84      0.83       278

# %%
# Compute confusion matrix for testing data
cnf_matrix = confusion_matrix(y_test, pred, labels=[1,0])
# Plot confusion matrix
plot_confusion_matrix(cnf_matrix, classes=['Attrition=1','Attrition=0'],normalize= False,  title='Test Confusion matrix')

# %% [markdown]
#  ### After setting the random state 170 , We got the accuracy score is 84%

# %% [markdown]
# ##  Cross validation for Decision Tree

# %%
cr3 = cross_val_score(dt,x,y,cv =15)*100
cross_val_dt =cr3.mean() 
cross_val.append(cross_val_dt)
print("Cross validation score of Decision Tree model",cross_val_dt)
# Out:
# Cross validation score of Decision Tree model 77.06716534206016

# %% [markdown]
# ### Difference between model accuracy and cross validation accuracy score is 7

# %% [markdown]
# ## Model Building using ada boost

# %%
#split data into train and test, model will be build on training data and tested on test data
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.20,random_state = 7)

# %%
# creating object for AdaBOOst
ada = AdaBoostClassifier()
# model training
ada.fit(x_train,y_train)
# predict the training score
y_pred = ada.predict(x_train)
training_score_ada = accuracy_score(y_train,y_pred)*100
training_score.append(training_score_ada)
print('Training score',training_score_ada)
pred = ada.predict(x_test)
testing_score_ada =accuracy_score(y_test,pred)*100 
testing_score.append(testing_score_ada)
print('Testing score',testing_score_ada)
print(classification_report(y_test,pred))
# Out:
# Training score 91.25338142470694
# Testing score 89.568345323741
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       229
#            1       0.81      0.53      0.64        49
#
#     accuracy                           0.90       278
#    macro avg       0.86      0.75      0.79       278
# weighted avg       0.89      0.90      0.89       278

# %%
# Compute confusion matrix for testing data
cnf_matrix = confusion_matrix(y_test, pred, labels=[1,0])
# Plot confusion matrix
plot_confusion_matrix(cnf_matrix, classes=['Attrition=1','Attrition=0'],normalize= False,  title='Test Confusion matrix')

# %% [markdown]
# ### After setting the random state = 7 , We got the accuracy score is 90 %

# %% [markdown]
# ## Cross validation for ADA BOOST

# %%
cr4 = cross_val_score(ada,x,y,cv =17)*100
cross_val_ada =cr4.mean()
cross_val.append(cross_val_ada)
print("Cross validation score of ADA BOOST",cross_val_ada)
# Out:
# Cross validation score of ADA BOOST 85.15064562410329

# %% [markdown]
# ### Difference between model accuracy and cross validation accuracy score is 5

# %% [markdown]
# ## Model Building using XGBoost

# %%
#split data into train and test, model will be build on training data and tested on test data
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.20,random_state = 245)

# %%
import xgboost as xgb
# creating object for XGBOOst
xgb = xgb.XGBClassifier()
# model training
xgb.fit(x_train,y_train)
# predict the training score
y_pred = xgb.predict(x_train)
training_score_xgb = accuracy_score(y_train,y_pred)*100
training_score.append(training_score_xgb)
print('Training score',training_score_xgb)
pred = xgb.predict(x_test)
testing_score_xgb = accuracy_score(y_test,pred)*100
testing_score.append(testing_score_xgb)
print('Testing score',testing_score_xgb)
print(classification_report(y_test,pred))
# Out:
# Training score 100.0
# Testing score 87.05035971223022
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.93       238
#            1       0.59      0.33      0.42        40
#
#     accuracy                           0.87       278
#    macro avg       0.74      0.64      0.67       278
# weighted avg       0.85      0.87      0.85       278

# %%
# Compute confusion matrix for testing data
cnf_matrix = confusion_matrix(y_test, pred, labels=[1,0])
# Plot confusion matrix
plot_confusion_matrix(cnf_matrix, classes=['Attrition=1','Attrition=0'],normalize= False,  title='Test Confusion matrix')

# %% [markdown]
# ### After setting the random state = 245 , We got the accuracy score is 87 %

# %% [markdown]
# ## Cross validation for XGBOOST

# %%
cr5 = cross_val_score(xgb,x,y,cv =17)*100
cross_val_ada =cr5.mean()
cross_val.append(cross_val_ada)
print("Cross validation score of XGBOOST",cross_val_ada)
# Out:
# Cross validation score of XGBOOST 85.51286820057743

# %% [markdown]
# ### Difference between model accuracy and cross validation accuracy score is 1.5

# %% [markdown]
# ## Model Building using LogisticRegression

# %%
#split data into train and test, model will be build on training data and tested on test data
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.20,random_state = 111)

# %%
from sklearn.linear_model import LogisticRegression

# %%
# creating object for LogisticRegression
lr = LogisticRegression()
# model training
lr.fit(x_train,y_train)
# predict the training score
y_pred = lr.predict(x_train)
training_score_lr = accuracy_score(y_train,y_pred)*100
training_score.append(training_score_lr)
print('Training score',training_score_lr)
pred = lr.predict(x_test)
testing_score_lr = accuracy_score(y_test,pred)*100
testing_score.append(testing_score_lr)
print('Testing score',testing_score_lr)
print(classification_report(y_test,pred))
# Out:
# Training score 88.18755635707845
# Testing score 88.12949640287769
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93       238
#            1       0.65      0.38      0.48        40
#
#     accuracy                           0.88       278
#    macro avg       0.78      0.67      0.70       278
# weighted avg       0.87      0.88      0.87       278

# %%
# Compute confusion matrix for testing data
cnf_matrix = confusion_matrix(y_test, pred, labels=[1,0])
# Plot confusion matrix
plot_confusion_matrix(cnf_matrix, classes=['Attrition=1','Attrition=0'],normalize= False,  title='Test Confusion matrix')

# %% [markdown]
# ### After setting the random state = 111 , We got the accuracy score is 88%

# %% [markdown]
# ## Cross validation for LogisticRegression

# %%
cr6 = cross_val_score(lr,x,y,cv =17)*100
cross_val_ada =cr6.mean()
cross_val.append(cross_val_ada)
print("Cross validation score of LogisticRegression",cross_val_ada)
# Out:
# Cross validation score of LogisticRegression 87.09637423171617

# %% [markdown]
# ### Difference between model accuracy and cross validation accuracy score is 1

# %% [markdown]
# ## Compare the models

# %%
# create a list of labels of build models
label = ['KNN','Random Forest','Decision Tree','AdaBoost','XGBoost','LogisticRegression']
print(label)
print(training_score)
print(testing_score)
print(cross_val)
# Out:
# ['KNN', 'Random Forest', 'Decision Tree', 'AdaBoost', 'XGBoost', 'LogisticRegression']
# [86.83498647430116, 100.0, 100.0, 91.25338142470694, 100.0, 88.18755635707845]
# [86.6906474820144, 90.28776978417267, 83.81294964028777, 89.568345323741, 87.05035971223022, 88.12949640287769]
# [83.7052978372921, 84.86104468887825, 77.06716534206016, 85.15064562410329, 85.51286820057743, 87.09637423171617]

# %%
# create dataframe
score_df = pd.DataFrame({'Model name':label,'Training Score':training_score,'Testing Score':testing_score,'Cross validation Score':cross_val})
score_df
# Out:
#            Model name  Training Score  Testing Score  Cross validation Score
# 0                 KNN       86.834986      86.690647               83.705298
# 1       Random Forest      100.000000      90.287770               84.861045
# 2       Decision Tree      100.000000      83.812950               77.067165
# 3            AdaBoost       91.253381      89.568345               85.150646
# 4             XGBoost      100.000000      87.050360               85.512868
# 5  LogisticRegression       88.187556      88.129496               87.096374

# %% [markdown]
#  ###  as per my observation , I choose LogisticRegression as the best model as it's Training and Testing score are more than other models and model accuracy and cross val score difference  is also least.

# %% [markdown]
# ## HYPERPARAMETER TUNING

# %%
lr=LogisticRegression()

# %%
params = {
    'n_jobs':[50,60],
    'max_iter':[100],
    'fit_intercept':[True,False],
    'random_state':[30,40,50],
    'dual':[True,False]       }

# %%
grd = GridSearchCV(lr,param_grid = params)
grd.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid={'dual': [True, False], 'fit_intercept': [True, False],
#                          'max_iter': [100], 'n_jobs': [50, 60],
#                          'random_state': [30, 40, 50]})

# %%
lr = grd.best_estimator_
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(n_jobs=50, random_state=30)

# %%
pred = lr.predict(x_test)
accuracy_score(y_test,pred)
# Out:
# 0.8812949640287769

# %% [markdown]
# ## ROC AUC Curve

# %%
from sklearn.metrics import plot_roc_curve

# %%
disp = plot_roc_curve(lr,x_train,y_train)
plot_roc_curve(dt,x_train,y_train,ax = disp.ax_)
plot_roc_curve(rf,x_train,y_train,ax = disp.ax_)
plot_roc_curve(ada,x_train,y_train,ax = disp.ax_)
plot_roc_curve(knn,x_train,y_train,ax = disp.ax_)
plot_roc_curve(xgb,x_train,y_train,ax = disp.ax_)
plt.legend(prop={'size':10},loc = 'lower right')
plt.show()

# %%
disp = plot_roc_curve(lr,x_test,y_test)
plot_roc_curve(dt,x_test,y_test,ax = disp.ax_)
plot_roc_curve(rf,x_test,y_test,ax = disp.ax_)
plot_roc_curve(ada,x_test,y_test,ax = disp.ax_)
plot_roc_curve(knn,x_test,y_test,ax = disp.ax_)
plot_roc_curve(xgb,x_test,y_test,ax = disp.ax_)
plt.legend(prop={'size':10},loc = 'lower right')
plt.show()

# %% [markdown]
# # save the final model

# %%
import joblib
joblib.dump(lr,'HR Analytics.pkl')
# Out:
# ['HR Analytics.pkl']

# %% [markdown]
# # Model is Completed
